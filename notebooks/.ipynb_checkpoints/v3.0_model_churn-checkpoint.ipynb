# %% [markdown]
# # PA003: Churn Predict

# %% [markdown]
#  **THE TOPBANK COMPANY**
# - A Bank Services Company, with main operations on Europe.
# - Offers financial products such as bank account, investments and insurance.
# - Business Model: banking services through physical agencies and online.
# - Main Product: bank account without costs, valid for 12 months. After this period, the account must be renovated.
# - Bank account revenue per client:
#     - 15% of client's estimated salary, for clients with estimated income lower than the average;
#     - 20% of client's estimated salary, for clients with estimated income greater than the average.
#
# **Problem**
# - Clients' cancellation rate increased significantly in the last few months.
#
# **Goal**
# - Reduce clients' churn rate, that is, to avoid that the client cancel the contract and don't renovate it for more 12 months.
#
# **Deliverables**
# - Model's performance and results report with the following topics:
#     - What's the company's current churn rate?
#     - How the churn rate varies per month?
#     - What's the model's performance to label the clients as churns?
#     - What's the company's revenue, if the company avoids the customers to get into churn through the developed model?
# - Possible measure: discount coupon or other financial incentive.
#     - Which customers could receive an incentive and at what cost, in order to maximize the ROI (Return on investment)? (the sum of incentives shall not exceed $ 10,000.00.

# %% [markdown]
#  - **PERGUNTAS:**
#
# 1. Qual a taxa de Churn atual da empresa?
# 2. Qual a Performance do modelo em classificar os clientes como churns?
# 3. Qual o retorno esperado, em termos de faturamento, se a empresa utilizar seu modelo para evitar o churn dos clientes?
# 4. Para quais clientes você daria um incentivo financeiro e qual seria esse valor, de modo a maximizar o ROI (Retorno sobre o investimento)?
# 5. Lembrando que a soma dos incentivos para cada cliente não pode ultrapassar os R$10.000.

# %% [markdown]
# # 0.0 Import

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import inflection
import math
import pickle
import inflection
import ROI
import os

# statistics
from scipy import stats

# save files
import pickle

from IPython.core.display          import HTML
from scipy.stats import shapiro, chi2_contingency

# stratified sampling
from sklearn.model_selection import StratifiedShuffleSplit

from sklearn                       import preprocessing            as pp
from sklearn.preprocessing   import OneHotEncoder
from sklearn.compose         import make_column_transformer
from scikitplot.metrics import plot_cumulative_gain, plot_lift_curve
import scikitplot as skplt
from BorutaShap import BorutaShap

from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.pipeline        import make_pipeline
# from sklearn.model_selection import train_test_split
# from sklearn.model_selection import cross_val_score, GridSearchCV
from catboost import CatBoostClassifier, metrics, Pool
from yellowbrick.classifier import ClassPredictionError, ConfusionMatrix, ClassificationReport, ROCAUC, ClassPredictionError, DiscriminationThreshold

from sklearn.model_selection import cross_validate, cross_val_predict, RandomizedSearchCV

# model's metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score,\
confusion_matrix, matthews_corrcoef, make_scorer, roc_curve, precision_recall_curve

# import packages for hyperparameters tuning
from hyperopt import STATUS_OK, Trials, fmin, hp, tpe

from xgboost import XGBClassifier
from imblearn.combine import SMOTETomek 


# from sklearn.preprocessing import StandardScaler, MinMaxScaler , RobustScaler


import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 0.1.Helper function

# %%
def my_settings():
    # %matplotlib inline
    
    # plotly settings
    plt.style.use( 'ggplot' )
    plt.rcParams['figure.figsize'] = [25, 12]
    plt.rcParams['font.size'] = 8
 
    # notebook settings
    display(HTML('<style>.container{width:100% !important;}</style>'))
    np.set_printoptions(suppress=True)
    pd.set_option('display.float_format', '{:.3f}'.format)
    
    # seaborn settings
    sns.set(rc={'figure.figsize':(25,12)})
    sns.set_theme(style = 'darkgrid', font_scale = 1)
my_settings()
# Out:
# <style>.container{width:100% !important;}</style>

# %%
# Save figures function
PROJECT_ROOT_DIR = "."
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images")
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
# Rename columns function 
def rename_columns(df1):
    # get current columns
    old_columns=list(df1.columns)
    
    # apply snakecase to columns names
    snakecase = lambda x : inflection.underscore(x)
    new_columns = map(snakecase , old_columns)

    # rename columns
    df1.columns = new_columns    
    return df1

# %%
# Feature Engineering Function 
def feature_engineering(df2):
    
    # balance_per_age
    balance_age = df2[['balance', 'age']].groupby('age').mean().reset_index()
    balance_age.columns = ['age' , 'balance_age']
    
    # merge
    df2 = pd.merge(df2, balance_age, on = 'age' ,  how = 'left')
    
    # balance_country
    balance_country = df2.loc[:, ['geography', 'balance']].groupby('geography').mean().reset_index()
    balance_country.columns = ['geography', 'balance_per_country']
    
    # merge
    df2 = pd.merge(df2, balance_country, on = 'geography', how = 'left')
    
    # balance_tenure
    balance_tenure = df2.loc[:, ['tenure', 'balance']].groupby('tenure').mean().reset_index()
    balance_tenure.columns = ['tenure', 'LTV']
    
    # merge
    df2 = pd.merge(df2, balance_tenure, on = 'tenure', how = 'left')
    
    # salary_gender
    estimated_salary_gender = df2.loc[:, ['gender', 'estimated_salary']].groupby('gender').mean().reset_index()
    estimated_salary_gender.columns = ['gender', 'estimated_salary_per_gender']
    
    # merge
    df2 = pd.merge(df2, estimated_salary_gender, on = 'gender', how = 'left')
    
    df2 = df2.drop('balance', axis = 1)

    
    
    return df2

# %%
 def numerical_descriptive_statistical(num_attributes):
        
    """
    Shows the main values  for descriptive statistics in numerical variables.

    Args:
        data ([float64 and int64]): Insert all numerical attributes in the dataset

    Returns:
        [dataframe]: A dataframe with mean, median, std deviation, skewness, kurtosis, min, max and range
    """
            
    # Central Tendency - Mean, Median
    ct1 = pd.DataFrame(num_attributes.apply(np.mean)).T
    ct2 = pd.DataFrame(num_attributes.apply(np.median)).T

    # Dispersion - std, min, max, range, skew, kurtosis, Shapiro-Wilk Test
    d1 = pd.DataFrame(num_attributes.apply(np.std)).T
    d2 = pd.DataFrame(num_attributes.apply(min)).T
    d3 = pd.DataFrame(num_attributes.apply(max)).T
    d4 = pd.DataFrame(num_attributes.apply(lambda x: x.max() - x.min())).T
    d5 = pd.DataFrame(num_attributes.apply(lambda x: x.skew())).T
    d6 = pd.DataFrame(num_attributes.apply(lambda x: x.kurtosis())).T
    d7 = pd.DataFrame(num_attributes.apply(lambda x: 'not normal' if shapiro(x.sample(5000))[1] < 0.05 else 'normal')).T

    # concatenate
    m = pd.concat([d2, d3, d4, ct1, ct2, d1, d5, d6, d7]).T.reset_index()
    m.columns = ['attributes', 'min', 'max', 'range', 'mean', 'median', 'std', 'skew', 'kurtosis', 'shapiro']
    return m



def categorical_descriptive_statstical(data , col):
    """
    Shows the the absolute and percent values in categorical variables.

    Args:
       data ([object]): Insert all categorical attributes in the dataset

    Returns:
        [dataframe]: A dataframe with absolute and percent values
    """
    return pd.DataFrame({'absolute' : data[col].value_counts() , 'percent %': data[col].value_counts(normalize = True) * 100})

# %%
# point biserial correlation coefficient heatmap function
def point_bi_corr(a, b):
    # a: input dataframe with binary variable
    # b: input dataframe with continuous variable
    
    # get column name
    a_name = a.columns[0]
    b_name = b.columns[0]
    
    # transform dataframe to array
    a = a.values.reshape(-1)
    b = b.values.reshape(-1)
    
    # apply scipy's point-biserial
    stats.pointbiserialr(a, b)
    
    # correlation coefficient array
    c = np.corrcoef(a,b)
    
    # dataframe for heatmap
    df = pd.DataFrame(c, columns=[a_name, b_name], index=[a_name, b_name])
    
    # return heatmap
    return sns.heatmap(df, annot=True).set_title('{} x {} correlation heatmap'.format(a_name, b_name));

# %%
def correlation_matrix(data , method):
    """Generates a correlation matrix of numerical variables

    Args:correlation_matrix
        data ([DataFrame]): [The dataframe of the EDA]
        method ([string]): [The method used, it can be ‘pearson’, ‘kendall’ or ‘spearman’]

    Returns:
        [Image]: [The correlation matrix plot made with seaborn]
    """
    
    # correlation
    num_attributes = data.select_dtypes( include = ['int64' , 'float64'])
    correlation = num_attributes.corr( method = method)
#     correlation.append('exited')
    
#     df_corr = data[correlation].reset_index(drop=True)
#     df_corr['exited'] = df_corr['exited'].astype('int')
    
    # mask
    mask = np.zeros_like(correlation)
    mask = np.triu(np.ones_like(correlation , dtype = np.bool))
    
    # plot -  mask = mask ,
    ax = sns.heatmap(correlation , fmt = '.2f' , vmin = -1 , vmax = 1, annot =  True, cmap = 'YlGnBu' , square = True)
    
    return ax

# %%
 # Model's performance function
def performance(model, x_train, y_train):
    # define scoring metrics
    scoring = {'accuracy': 'accuracy',
               'precision': make_scorer(precision_score),
               'recall': make_scorer(recall_score),
               'f1_score': make_scorer(f1_score),
               'roc_auc_score': make_scorer(roc_auc_score),
               'mcc': make_scorer(matthews_corrcoef)}

    # calculate scores with cross_validate
    scores = cross_validate(model, x_train, y_train, cv=10, scoring=scoring)

    # performance data frame
    performance = pd.DataFrame.from_dict(scores).drop(['fit_time', 'score_time'], axis=1)
    performance = pd.DataFrame(performance.mean()).T
    return performance

 # Model's performance on test set function
def performance_test(model_name, model, x_test, y_test):
    # predcitions
    yhat = model.predict(x_test)
    
    # Performance metrics
    precision = precision_score(y_test, yhat)
    recall = recall_score(y_test, yhat)
    f1 = f1_score(y_test, yhat)
    roc_auc = roc_auc_score(y_test, yhat)
    mcc = matthews_corrcoef(y_test, yhat)

    # Performance dataframe
    performance_df = pd.DataFrame({'precision': precision, 'recall': recall, 'f1_score': f1, 
                               'roc_auc_score': roc_auc, 'mcc': mcc}, index=[model_name])

    # confusion matrix
    cm = confusion_matrix(y_test, yhat)

    # dataframe for heatmap
    cm_df = pd.DataFrame(cm, columns=['predicted_not_churn', 'predicted_churn'], 
                         index=['actual_not_churn', 'actual_churn'])
    
    return performance_df, cm_df

# %%
def without_hue(plot, feature):
    total = len(feature)
    for p in plot.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width() / 2 - 0.05
        y = p.get_y() + p.get_height()
        plot.annotate(percentage, (x, y), size = 12)

def plot_cat_overview(df, cat_attributes, target):
    
    cat_attributes.remove(target)

    plots_lin = math.ceil(len(cat_attributes)/2)

    fig, axs = plt.subplots(plots_lin,2, figsize=(25, 10), facecolor='w', edgecolor='k')
    fig.subplots_adjust(hspace = .5, wspace=.20)
    axs = axs.ravel()    

    for c in range(len(cat_attributes)):
        ax1 = sns.countplot(ax=axs[c], x=cat_attributes[c],hue=target, data=df)
        without_hue(ax1,df1.exited)

# %%
def sum_of_na (data):
    return pd.DataFrame({'Sum of NA' : data.isna().sum(), '% NA': data.isna().sum()/data.shape[0]})

# %%
def lift_score(y, y_pred, **kwargs):    
    df = pd.DataFrame()
    df['true'] = y
    df['pred'] = y_pred
    df.sort_values('pred', ascending=False, inplace=True)
    N = len(df)
    churn_total = df['true'].sum() / N
    n = int(np.ceil(.1 * N)) 
    data_here = df.iloc[:n, :]
    churn_here = data_here['true'].sum() / n
    lift = churn_here / churn_total
    return lift

# %%
 def knapsack(W, wt, val):
    n = len(val)
    K = [[0 for x in range(W + 1)] for x in range(n + 1)]
    for i in range(n + 1):
        for w in range(W + 1):
            if i == 0 or w == 0:
                K[i][w] = 0
            elif wt[i-1] <= w:
                K[i][w] = max(val[i-1] + K[i-1][w-wt[i-1]], K[i-1][w])
            else:
                K[i][w] = K[i-1][w]
    max_val = K[n][W]
    keep = [False] * n
    res = max_val
    w = W
    for i in range(n, 0, -1):
        if res <= 0: break
        if res == K[i - 1][w]: continue
        else:
            keep[i - 1] = True
            res = res - val[i - 1]
            w = w - wt[i - 1]
    del K
    return max_val, keep

# %%
def get_ROI(X_val, y_val, yproba, threshold=.8, name='XGBoost', investment=10_000, gift=100):
    roi = ROI(X_val, y_val, yproba, threshold=threshold, name=name)
    roi.print_performance(investment=investment, gift=gift)
    return roi

# %%
def cross_validation(num_fold, x_train, y_train, model, model_name, balance_model=False, verbose=False):
    # generate k-fold
    kfold = ms.StratifiedKFold( n_splits=num_fold, shuffle=True, random_state=32 )

    # create empty metrics list
    acc_list = []
    prec_list = []
    recall_list = []
    roc_auc_list = []
    f1_list = []
    logloss_list = []
    brier_list = []

    # sequence of loop for verbose
    i = 1
    
    # interation to measure performance
    for train_index, val_index in kfold.split(x_train, y_train):
        if verbose:
            print(f'Fold Number:{i}/{num_folds}')

        # split data into training and test set
        x_train_cv = x_train.iloc[train_index]
        y_train_cv = y_train.iloc[train_index]

        x_validation_cv = x_train.iloc[val_index]
        y_validation_cv = y_train.iloc[val_index]
        
        # balance of dataset
        if balance_model != False:
            # resample the dataset
            x_train_cv, y_train_cv = balance_model.fit_resample(x_train_cv, y_train_cv)

        # training model
        model.fit(x_train_cv, y_train_cv)

        # prediction
        y_pred_cv = model.predict(x_validation_cv)
        
        # probabilistic prediction
        y_pred_proba_cv = model.predict_proba(x_validation_cv)

        # select only true probabilistc
        y_pred_proba_cv_true = y_pred_proba_cv[:,1]

        # performance metrics
        # accuracy
        acc_model = accuracy_score(y_validation_cv, y_pred_cv)
        acc_list.append(acc_model)
        
        # precision
        prec_model = precision_score(y_validation_cv, y_pred_cv)
        prec_list.append(prec_model)
        
        # recall
        recall_model = recall_score(y_validation_cv, y_pred_cv)
        recall_list.append(recall_model)
        
        # roc_auc_score
        roc_auc_model = roc_auc_score(y_validation_cv, y_pred_cv)
        roc_auc_list.append(roc_auc_model)
        
        # f1 score
        f1_model = f1_score(y_validation_cv, y_pred_cv)
        f1_list.append(f1_model)
        
        # logistic loss
        log_loss_model = log_loss(y_validation_cv, y_pred_proba_cv)
        logloss_list.append(log_loss_model)
        
        # brier loss
        brier_loss_model = brier_score_loss(y_validation_cv, y_pred_proba_cv_true)
        brier_list.append(brier_loss_model)
        
        # actual fold 
        i += 1
    
    # cross validation accuracy
    acc_cv_mean = np.round(np.mean(acc_list), 6)
    acc_cv_std = np.round(np.std(acc_list), 6)
    
    # cross validation precision
    prec_cv_mean = np.round(np.mean(prec_list), 6)
    prec_cv_std = np.round(np.std(prec_list), 6)
    
    # cross validation recall
    recall_cv_mean = np.round(np.mean(recall_list), 6)
    recall_cv_std = np.round(np.std(recall_list), 6)
        
    # cross validation F1 score
    f1_cv_mean = np.round(np.mean(f1_list), 6)
    f1_cv_std = np.round(np.std(f1_list), 6)
    
    # cross validation ROC-AUC
    roc_auc_cv_mean = np.round(np.mean(roc_auc_list), 6)
    roc_auc_cv_std = np.round(np.std(roc_auc_list), 6)
    
    # cross validation log loss
    logloss_cv_mean = np.round(np.mean(logloss_list), 6)
    logloss_cv_std =np.round(np.std(logloss_list), 6)
    
    # cross validation brier loss
    brier_cv_mean = np.round(np.mean(brier_list), 6)
    brier_cv_std = np.round(np.std(brier_list), 6)
    
    # cross-validation dataframe
    performance_cv = pd.DataFrame({'model': f'{model_name}', 
                                   'accuracy': f'{acc_cv_mean} +/- {acc_cv_std}', 
                                   'precision': f'{prec_cv_mean} +/- {prec_cv_std}', 
                                   'recall': f'{recall_cv_mean} +/- {recall_cv_std}', 
                                   'f1_score': f'{f1_cv_mean} +/- {f1_cv_std}', 
                                   'roc_auc': f'{roc_auc_cv_mean} +/- {roc_auc_cv_std}', 
                                   'log_loss': f'{logloss_cv_mean} +/- {logloss_cv_std}', 
                                   'brier_score': f'{brier_cv_mean} +/- {brier_cv_std}'}, 
                                  index=[0])
    
    return performance_cv

# %% [markdown]
# ## 0.2. Loading Data

# %%
df_raw = pd.read_csv(r'~/projetos/churn_predict/data/raw/churn.csv')

# %%
df_raw.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2      0.000              1          1               1
# 1       1  83807.860              1          0               1
# 2       8 159660.800              3          1               0
# 3       1      0.000              2          0               0
# 4       2 125510.820              1          1               1
#
#    EstimatedSalary  Exited
# 0       101348.880       1
# 1       112542.580       0
# 2       113931.570       1
# 3        93826.630       0
# 4        79084.100       0

# %%
 # Apply stratified sampling in order to keep target variable proportion in the train and test sets
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, test_index in split.split(df_raw, df_raw['Exited']):
    train_set = df_raw.loc[train_index]
    test_set = df_raw.loc[test_index]

# %% [markdown]
# # 1.0. Data Description

# %% [markdown]
#  - **RowNumber**      : O número da coluna.
#  - **CustomerID**     : Identificador único do cliente.
#  - **Surname**        : Sobrenome do cliente.
#  - **CreditScore**    : A pontuação de Crédito do cliente para o mercado de consumo.
#  - **Geography**      : O país onde o cliente reside.
#  - **Gender**         : O gênero do cliente.
#  - **Age**            : A idade do cliente.
#  - **Tenure**         : Número de anos que o cliente permaneceu ativo.
#  - **Balance**        : Valor monetário que o cliente tem em sua conta bancária.
#  - **NumOfProducts**  : O número de produtos comprado pelo cliente no banco.
#  - **HasCrCard**      : Indica se o cliente possui ou não cartão de crédito.
#  - **IsActiveMember** : Indica se o cliente fez pelo menos uma movimentação na conta bancário dentro de 12 meses.
#  - **EstimateSalary** : Estimativa do salário mensal do cliente.
#  - **Exited**         : Indica se o cliente está ou não em Churn.

# %%
df1 = train_set.copy()

# %%
df1.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df1.duplicated('CustomerId').sum()
# Out:
# 0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8000 entries, 2151 to 6206
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        8000 non-null   int64
#  1   CustomerId       8000 non-null   int64
#  2   Surname          8000 non-null   object
#  3   CreditScore      8000 non-null   int64
#  4   Geography        8000 non-null   object
#  5   Gender           8000 non-null   object
#  6   Age              8000 non-null   int64
#  7   Tenure           8000 non-null   int64
#  8   Balance          8000 non-null   float64
#  9   NumOfProducts    8000 non-null   int64
#  10  HasCrCard        8000 non-null   int64
#  11  IsActiveMember   8000 non-null   int64
#  12  EstimatedSalary  8000 non-null   float64
#  13  Exited           8000 non-null   int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 937.5+ KB

# %% [markdown]
# ## 1.1 Rename Columns

# %%
old_columns=list(df1.columns)

snakecase = lambda x : inflection.underscore(x)
new_columns = map(snakecase , old_columns)

# rename columns
df1.columns = new_columns

# %% [markdown]
# ## 1.2. Data Dimensions

# %%
print('Numbers of rows: {}'.format(df1.shape[0]))
print('Numbers of cols: {}'.format(df1.shape[1]))
# Out:
# Numbers of rows: 8000
# Numbers of cols: 14

# %% [markdown]
# ## 1.3. Data Types

# %%
df1.head()
# Out:
#       row_number  customer_id   surname  credit_score geography  gender  age  \
# 2151        2152     15588614    Walton           753    France    Male   57
# 8392        8393     15641158   Belcher           739   Germany    Male   32
# 5006        5007     15750014   Chikere           755   Germany  Female   37
# 4117        4118     15663964  Pagnotto           561    France    Male   37
# 7182        7183     15573520    Rhodes           692   Germany    Male   49
#
#       tenure    balance  num_of_products  has_cr_card  is_active_member  \
# 2151       7      0.000                1            1                 0
# 8392       3 102128.270                1            1                 0
# 5006       0 113865.230                2            1                 1
# 4117       5      0.000                2            1                 0
# 7182       6 110540.430                2            0                 1
#
#       estimated_salary  exited
# 2151        159475.080       1
# 8392         63981.370       1
# 5006        117396.250       0
# 4117         83093.250       0
# 7182        107472.990       0

# %%
df1.dtypes
# Out:
# row_number            int64
# customer_id           int64
# surname              object
# credit_score          int64
# geography            object
# gender               object
# age                   int64
# tenure                int64
# balance             float64
# num_of_products       int64
# has_cr_card           int64
# is_active_member      int64
# estimated_salary    float64
# exited                int64
# dtype: object

# %% [markdown]
# ### 1.3.1. Change Data Types

# %%
df1.exited = df1.exited.astype('bool')
df1.has_cr_card = df1.has_cr_card.astype('bool')
df1.is_active_member= df1.is_active_member.astype('bool')

# %% [markdown]
# ### 1.3.2. Check unique values

# %%
df1.nunique()
# Out:
# row_number          8000
# customer_id         8000
# surname             2620
# credit_score         456
# geography              3
# gender                 2
# age                   69
# tenure                11
# balance             5108
# num_of_products        4
# has_cr_card            2
# is_active_member       2
# estimated_salary    7999
# exited                 2
# dtype: int64

# %% [markdown]
# ### 1.3.3. Remove Variables

# %%
cols_drop = ['row_number', 'surname', 'customer_id']
df1 = df1.drop(cols_drop , axis = 1)

# %% [markdown]
# ## 1.4. Check NA

# %%
df1.isna().sum()
# Out:
# credit_score        0
# geography           0
# gender              0
# age                 0
# tenure              0
# balance             0
# num_of_products     0
# has_cr_card         0
# is_active_member    0
# estimated_salary    0
# exited              0
# dtype: int64

# %% [markdown]
# ## 1.5. Data Descriptive

# %%
num_attributes = df1.select_dtypes(include=['int64', 'float64'])
cat_attributes = df1.select_dtypes(exclude=['int64', 'float64'])

# %% [markdown]
# ### 1.5.1. Numerical Attributes

# %%
m = numerical_descriptive_statistical(num_attributes)
m
# Out:
#          attributes     min        max      range      mean    median  \
# 0      credit_score 350.000    850.000    500.000   650.753   652.000
# 1               age  18.000     92.000     74.000    38.947    37.000
# 2            tenure   0.000     10.000     10.000     5.017     5.000
# 3           balance   0.000 238387.560 238387.560 76381.207 97055.145
# 4   num_of_products   1.000      4.000      3.000     1.530     1.000
# 5  estimated_salary  11.580 199992.480 199980.900 99730.812 99446.940
#
#         std   skew kurtosis     shapiro
# 0    96.590 -0.080   -0.419  not normal
# 1    10.526  1.036    1.459  not normal
# 2     2.897  0.013   -1.173  not normal
# 3 62298.160 -0.142   -1.492  not normal
# 4     0.582  0.756    0.637  not normal
# 5 57331.533  0.007   -1.175  not normal

# %% [markdown]
# ### 1.5.2. Categorical Attributes

# %%
cat_attributes.columns
# Out:
# Index(['geography', 'gender', 'has_cr_card', 'is_active_member', 'exited'], dtype='object')

# %%
x = df1[['geography' , 'exited']].groupby('geography').count().reset_index()
x
# Out:
#   geography  exited
# 0    France    3993
# 1   Germany    2005
# 2     Spain    2002

# %%
plot_cat_overview(cat_attributes, list(cat_attributes.columns), 'exited')

# %%
categorical_descriptive_statstical(cat_attributes , 'geography')
# Out:
#          absolute  percent %
# France       3993     49.913
# Germany      2005     25.062
# Spain        2002     25.025

# %%
categorical_descriptive_statstical(cat_attributes , 'gender')
# Out:
#         absolute  percent %
# Male        4387     54.837
# Female      3613     45.163

# %%
categorical_descriptive_statstical(cat_attributes , 'has_cr_card')
# Out:
#        absolute  percent %
# True       5670     70.875
# False      2330     29.125

# %%
categorical_descriptive_statstical(cat_attributes , 'is_active_member')
# Out:
#        absolute  percent %
# True       4119     51.487
# False      3881     48.512

# %%
categorical_descriptive_statstical(cat_attributes , 'exited')
# Out:
#        absolute  percent %
# False      6370     79.625
# True       1630     20.375

# %% [markdown]
# ### 1.5.3. Multivariate Analysis

# %%
correlation_matrix(df1 , 'spearman')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 1.5.4. Outliers Numerical Attributes

# %%
num_cols = num_attributes.columns.tolist()

# %%
i = 1
for col in df1[num_cols]:
    plt.subplot(2,3,i)
    ax = sns.boxplot( data = df1 , x = col)
    i += 1

# %% [markdown]
#  **Important informations:**
#
# - There are outliers in **credit_score, num_of_products and age**
# - The **churn ratio is 20.37%**
# - **70.6%** of the members **has credit card**
# - More than **50% of the clients** are **from France**

# %% [markdown]
# # 2.0. Feature Engineering

# %%
df2 = df1.copy()

# %%
df2.head()
# Out:
#       credit_score geography  gender  age  tenure    balance  num_of_products  \
# 2151           753    France    Male   57       7      0.000                1
# 8392           739   Germany    Male   32       3 102128.270                1
# 5006           755   Germany  Female   37       0 113865.230                2
# 4117           561    France    Male   37       5      0.000                2
# 7182           692   Germany    Male   49       6 110540.430                2
#
#       has_cr_card  is_active_member  estimated_salary  exited
# 2151         True             False        159475.080    True
# 8392         True             False         63981.370    True
# 5006         True              True        117396.250   False
# 4117         True             False         83093.250   False
# 7182        False              True        107472.990   False

# %% [markdown]
# ## 2.1. Balance_age

# %%
# balance_per_age
balance_age = df2[['balance', 'age']].groupby('age').mean().reset_index()
balance_age.columns = ['age' , 'balance_age']

# merge

df2 = pd.merge(df2, balance_age, on = 'age' ,  how = 'left')

# %% [markdown]
# ## 2.2. Balance_country

# %%
balance_country = df2.loc[:, ['geography', 'balance']].groupby('geography').mean().reset_index()
balance_country.columns = ['geography', 'balance_per_country']

# merge
df2 = pd.merge(df2, balance_country, on = 'geography', how = 'left')

# %% [markdown]
# ## 2.3. Balance_tenure

# %%
balance_tenure = df2.loc[:, ['tenure', 'balance']].groupby('tenure').mean().reset_index()
balance_tenure.columns = ['tenure', 'LTV']

# merge
df2 = pd.merge(df2, balance_tenure, on = 'tenure', how = 'left')

# %% [markdown]
# ## 2.3. Salary_gender

# %%
estimated_salary_gender = df2.loc[:, ['gender', 'estimated_salary']].groupby('gender').mean().reset_index()
estimated_salary_gender.columns = ['gender', 'estimated_salary_per_gender']

# merge
df2 = pd.merge(df2, estimated_salary_gender, on = 'gender', how = 'left')

# %%
correlation_matrix(df2, 'pearson')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 3.0. Data Filtering

# %%
df3 = df2.copy()

# %% [markdown]
# # 4.0. Exploratoria Data Analysis (EDA)

# %%
df4 = df3.copy()

# %% [markdown]
# # 4.1. Bivariate Analysis

# %% [markdown]
# ### **H1. Churn should occur for clients with high salary**

# %% [markdown]
# - **TRUE** Churn occur for clients with high salary.

# %%
 # create auxiliary dataframes for exited = 0 and exited = 1
aux1_1 = df4[df4['exited']==0]
aux1_2 = df4[df4['exited']==1]

# plot estimated salary density distribution for exited = 0 and exited = 1
plt.figure(figsize=(12,6))
sns.distplot(aux1_2['estimated_salary'], color='orange', kde=True, label='churn')
sns.distplot(aux1_1['estimated_salary'], kde=True, label='not churn')
plt.title('Estimated Salary density distribution');
plt.legend();
save_fig('04_estimated_salary_density_distribution')
# Out:
# Saving figure 04_estimated_salary_density_distribution

# %%
aux1_2['estimated_salary'].describe()
# Out:
# count     1630.000
# mean    102026.976
# std      57949.861
# min         11.580
# 25%      52662.253
# 50%     104721.985
# 75%     151224.030
# max     199808.100
# Name: estimated_salary, dtype: float64

# %%
 # plot estimated_salary binned values of clients in churn
bins1 = list(np.arange(0, 2.01e5, 5e3))
aux1_2['salary_binned'] = pd.cut(aux1_2['estimated_salary'], bins=bins1)
plt.subplots(figsize=(12,6))
sns.countplot(x='salary_binned', data=aux1_2).set_title("estimated salary per group of 5k of clients in churn");
# rotate x axis
plt.xticks(rotation=90);

# %%
 # plot estimated_salary binned values of active clients
bins1 = list(np.arange(0, 2.01e5, 5e3))
aux1_1['salary_binned'] = pd.cut(aux1_1['estimated_salary'], bins=bins1)
plt.subplots(figsize=(12,6))
sns.countplot(x='salary_binned', data=aux1_1).set_title("estimated salary per group of 5k of active clients");
# rotate x axis
plt.xticks(rotation=90);

# %% [markdown]
# - Plot estimated salary percentage per group of 5k

# %%
# define salary percentage
aux1_1['salary_percentage'] = aux1_1['salary_binned'].value_counts(normalize=True)*100
aux1_2['salary_percentage'] = aux1_2['salary_binned'].value_counts(normalize=True)*100

# set up figure size
plt.subplots(figsize=(16,6))

# 1st plot
plt.subplot(1,2,1)
sns.barplot(x='salary_binned', y='salary_percentage', data=aux1_2).set_title('salary percentage of clients in churn')
# rotate x axis
plt.xticks(rotation=90);

# 2nd plot
plt.subplot(1,2,2)
sns.barplot(x='salary_binned', y='salary_percentage', data=aux1_1).set_title('salary percentage of active clients')
# rotate x axis
plt.xticks(rotation=90);

# %% [markdown]
# - Calculate the relative percentage of active clients and clients in churn per salary_binned

# %%
# set new bins in order to ease the analysis
bins2 = list(np.arange(0, 2.01e5, 20e3))

# create new dataframe
aux100 = df4[['estimated_salary', 'exited']]
aux100['salary_binned'] = pd.cut(aux100['estimated_salary'], bins=bins2)

# new dataframe with salary_binned, exited and number of clients
aux101 = aux100[['salary_binned', 'estimated_salary', 'exited']].\
groupby(['salary_binned', 'exited']).count().reset_index()

# rename new dataframe columns
aux101.columns = ['salary_binned', 'exited', 'clients']

# sum of clients in churn
clients_in_churn = aux101[aux101['exited'] == 1]['clients'].sum()

# sum of active clients
clients_not_churn = aux101[aux101['exited'] == 0]['clients'].sum()

# calculate the relative percentage of clients in churn and active clients
aux101['relative_percentage'] = aux101.\
apply(lambda x: ((x['clients'] / clients_in_churn)*100) if x['exited'] == 1 else ((x['clients'] / clients_not_churn)*100), axis=1)

aux101
# Out:
#            salary_binned  exited  clients  relative_percentage
# 0         (0.0, 20000.0]   False      628                9.859
# 1         (0.0, 20000.0]    True      160                9.816
# 2     (20000.0, 40000.0]   False      629                9.874
# 3     (20000.0, 40000.0]    True      160                9.816
# 4     (40000.0, 60000.0]   False      660               10.361
# 5     (40000.0, 60000.0]    True      140                8.589
# 6     (60000.0, 80000.0]   False      655               10.283
# 7     (60000.0, 80000.0]    True      162                9.939
# 8    (80000.0, 100000.0]   False      672               10.549
# 9    (80000.0, 100000.0]    True      156                9.571
# 10  (100000.0, 120000.0]   False      648               10.173
# 11  (100000.0, 120000.0]    True      173               10.613
# 12  (120000.0, 140000.0]   False      629                9.874
# 13  (120000.0, 140000.0]    True      168               10.307
# 14  (140000.0, 160000.0]   False      627                9.843
# 15  (140000.0, 160000.0]    True      163               10.000
# 16  (160000.0, 180000.0]   False      623                9.780
# 17  (160000.0, 180000.0]    True      186               11.411
# 18  (180000.0, 200000.0]   False      599                9.403
# 19  (180000.0, 200000.0]    True      162                9.939

# %% [markdown]
# ## H2. Churn should occur more for women than men.

# %% [markdown]
# **TRUE** Churn occur more for women than men.

# %%
# plot gender distribution
sns.countplot(x='gender', data=df4).set_title('number of clients per gender');

# %%
 # plot number of clients per gender and churn
plt.subplots(figsize=(10,6))
sns.countplot(x='gender', hue='exited', data=df4).set_title('number of clients per gender and churn');
save_fig('04_gender_churn')
# Out:
# Saving figure 04_gender_churn

# %%
 # plot number of clients per gender and churn
plt.subplots(figsize=(10,6))
sns.countplot(x='gender', hue='exited', data=df4).set_title('number of clients per gender and churn');
save_fig('04_gender_churn')
# Out:
# Saving figure 04_gender_churn

# %%
 # define dataframe for exited = 0 and exited = 1
aux3_1 = df4[df4['exited']==0]
aux3_2 = df4[df4['exited']==1]

# %%
 # plot gender distribution percentage

# set up figure size
plt.subplots(figsize=(12,6))

# 1st plot: gender percentage of clients not in churn
plt.subplot(1,2,1)
perc_not_churn = aux3_1['gender'].value_counts(normalize=True)*100
sns.barplot(x=perc_not_churn.index, y=perc_not_churn).set_title('gender percentage of clients not in churn');

# 2nd plot: gender percentage of clients in churn
plt.subplot(1,2,2)
perc_churn = aux3_2['gender'].value_counts(normalize=True)*100
sns.barplot(x=perc_churn.index, y=perc_churn, order=['Male', 'Female']).set_title('gender percentage of clients in churn');
save_fig('04_gender_percentage')
# Out:
# Saving figure 04_gender_percentage

# %%
perc_not_churn = aux3_1['gender'].value_counts(normalize=True)*100
perc_not_churn
# Out:
# Male     57.504
# Female   42.496
# Name: gender, dtype: float64

# %%
perc_not_churn = aux3_1['gender'].value_counts(normalize=True)*100
perc_not_churn
# Out:
# Male     57.504
# Female   42.496
# Name: gender, dtype: float64

# %% [markdown]
# - As previously checked, 4387 clients (54.8%) are men and 3613 clients (45.2%) are women.
# - For clients not in churn, 57.5% are men and 42.5% are women: the proportion of men is greater than the proportion considering the whole dataset (54.8%).
# - For clients in churn, 55.6% are women and 44.4% are men: the proportion is inverse compared to the whole dataset and for client not in churn, as for both of them the proportion of men is greater than the proportion of women.
# - Therefore, the hypothesis is true: churn occur more for women than men.

# %% [markdown]
# ## H3. Churn should not occur for active members.

# %% [markdown]
# **TRUE** Churn does not occur for active members.

# %%
df4['is_active_member'].value_counts()
# Out:
# True     4119
# False    3881
# Name: is_active_member, dtype: int64

# %%
df4['is_active_member'].value_counts(normalize=True)*100
# Out:
# True    51.487
# False   48.512
# Name: is_active_member, dtype: float64

# %% [markdown]
# - Plot is active member per churn

# %%
 # set up figure size
plt.subplots(figsize=(12,6))

sns.countplot(x='is_active_member', hue='exited', data=df4).set_title('active members distribution per churn');
save_fig('04_active_member_countplot')
# Out:
# Saving figure 04_active_member_countplot

# %%
 # define dataframes exited = 0 and exited = 1
aux5_1 = df4[df4['exited']==0]
aux5_2 = df4[df4['exited']==1]

# plot percentages

# set up figure size
plt.subplots(figsize=(12,6))

# 1st plot
plt.subplot(1,2,1)
active_perc_not_churn = aux5_1['is_active_member'].value_counts(normalize=True)*100
sns.barplot(x=active_perc_not_churn.index, y=active_perc_not_churn).\
set_title('active members percentage not in churn');

# 2nd plot
plt.subplot(1,2,2)
active_perc_churn = aux5_2['is_active_member'].value_counts(normalize=True)*100
sns.barplot(x=active_perc_churn.index, y=active_perc_churn).\
set_title('active members percentage in churn');

# %%
active_perc_not_churn
# Out:
# True    55.338
# False   44.662
# Name: is_active_member, dtype: float64

# %%
active_perc_churn
# Out:
# False   63.558
# True    36.442
# Name: is_active_member, dtype: float64

# %%
# new dataframe with is_active_member, exited and number of clients
aux500 = df4[['is_active_member','balance', 'exited']].groupby(['is_active_member', 'exited']).count().reset_index()
aux500.columns = ['is_active_member', 'exited', 'num_clients']

# sum of clients in churn
sum_churn = aux500[aux500['exited']==1]['num_clients'].sum()

# sum of clients not in churn
sum_not_churn = aux500[aux500['exited']==0]['num_clients'].sum()

# calculate relative percentage
aux500['relative_percentage'] = aux500.\
apply(lambda x: ((x['num_clients'] / sum_churn)*100) if x['exited'] == 1 else ((x['num_clients'] / sum_not_churn)*100), axis=1)

aux500
# Out:
#    is_active_member  exited  num_clients  relative_percentage
# 0             False   False         2845               44.662
# 1             False    True         1036               63.558
# 2              True   False         3525               55.338
# 3              True    True          594               36.442

# %% [markdown]
# - Plot is_active_member relative percentage

# %%
 # set up figure size
plt.subplots(figsize=(12,6))

sns.barplot(x='is_active_member', y='relative_percentage', hue='exited', data=aux500).\
set_title('Active members relative percentage');
save_fig('04_active_members_relative_percentage')
# Out:
# Saving figure 04_active_members_relative_percentage

# %% [markdown]
# - 51.5% of the clients are active members. 48.5% of the clients are not active members.
# - Clients not in churn: 55.3% are active members. 44.7% are not active members.
# - Clients in churn: 63.6% are not active members. 36.4% are active members, which corresponds to 594 clients, that is, even though they are active members, they decided to exit the bank.
# - Therefore, the hypothesis is true: churn does not occur for active members.

# %% [markdown]
# ## H4. Churn should not occur for clients with credit card.

# %% [markdown]
# **TRUE** Churn does not occur for clients with credit card.

# %%
df4['has_cr_card'].value_counts()
# Out:
# True     5670
# False    2330
# Name: has_cr_card, dtype: int64

# %%
df4['has_cr_card'].value_counts(normalize=True)*100
# Out:
# True    70.875
# False   29.125
# Name: has_cr_card, dtype: float64

# %% [markdown]
# - Plot clients with credit card distribution

# %%
# set up figure size
plt.subplots(figsize=(12,6))

sns.countplot(x='has_cr_card', hue='exited', data=df4);
save_fig('04_credit_card_countplot')
# Out:
# Saving figure 04_credit_card_countplot

# %%
 # define dataframe for exited = 0 and exited = 1
aux6_1 = df4[df4['exited']==0]
aux6_2 = df4[df4['exited']==1]

# plot percentages

# set up figure size
plt.subplots(figsize=(12,6))

# 1st plot: credit card distribution of clients not in churn
plt.subplot(1,2,1)
card_perc_not_churn = aux6_1['has_cr_card'].value_counts(normalize=True)*100
sns.barplot(x=card_perc_not_churn.index, y=card_perc_not_churn).\
set_title('credit card distribution of clients not in churn');

# 2nd plot: credit card distribution of clients in churn
plt.subplot(1,2,2)
card_perc_churn = aux6_2['has_cr_card'].value_counts(normalize=True)*100
sns.barplot(x=card_perc_churn.index, y=card_perc_churn).\
set_title('credit card distribution of clients in churn');

# %%
card_perc_not_churn
# Out:
# True    71.209
# False   28.791
# Name: has_cr_card, dtype: float64

# %%
card_perc_churn
# Out:
# True    69.571
# False   30.429
# Name: has_cr_card, dtype: float64

# %%
# new dataframe with has_cr_card, exited and number of clients
aux600 = df4[['has_cr_card','balance', 'exited']].groupby(['has_cr_card', 'exited']).count().reset_index()
aux600.columns = ['has_cr_card', 'exited', 'num_clients']

# sum of clients in churn
sum_churn = aux600[aux600['exited']==1]['num_clients'].sum()

# sum of clients not in churn
sum_not_churn = aux600[aux600['exited']==0]['num_clients'].sum()

# calculate relative percentage
aux600['relative_percentage'] = aux600.\
apply(lambda x: ((x['num_clients'] / sum_churn)*100) if x['exited'] == 1 else ((x['num_clients'] / sum_not_churn)*100), axis=1)

aux600
# Out:
#    has_cr_card  exited  num_clients  relative_percentage
# 0        False   False         1834               28.791
# 1        False    True          496               30.429
# 2         True   False         4536               71.209
# 3         True    True         1134               69.571

# %% [markdown]
# - Plot has_cr_card relative percentage

# %%
# set up figure size
plt.subplots(figsize=(12,6))

sns.barplot(x='has_cr_card', y='relative_percentage', hue='exited', data=aux600).\
set_title('Credit card relative percentage');
save_fig('04_credit_card_relative_percentage')
# Out:
# Saving figure 04_credit_card_relative_percentage

# %% [markdown]
# - 70.9% of the customers have credit card.
# - Clients not in churn: 71.2% have credit card. 28.8% have not credit card.
# - Clients in churn: 69.6% have credit card. 30.4% have not credit card.
# - The proportion of clients in churn without credit card (30.4%) is greater than the proportion of clients not in churn without credit card (28.8%).
# - The proportion of clients not in churn with credit card (71.2%) is greater than the proportion of clients in churn with credit card (69.6%).
# - Therefore, the hypothesis is True: churn does not occur for clients with credit card.

# %% [markdown]
# ## H5. Churn should occur for clients with a low credit score.

# %% [markdown]
# **TRUE** Churn occur for clients with a low credit score.

# %%
 # set dataframes for exited = 0 and exited = 1
aux7_1 = df4[df4['exited']==0]
aux7_2 = df4[df4['exited']==1]

# set up figure size
plt.subplots(figsize=(12,6))

sns.distplot(aux7_1['credit_score'], label='not churn');
sns.distplot(aux7_2['credit_score'], color='orange', label='churn');
plt.title('Credit score density distribution');
plt.legend();
save_fig('04_credit_score_density_distribution')
# Out:
# Saving figure 04_credit_score_density_distribution

# %%
df4['credit_score'].describe()
# Out:
# count   8000.000
# mean     650.753
# std       96.596
# min      350.000
# 25%      584.000
# 50%      652.000
# 75%      717.000
# max      850.000
# Name: credit_score, dtype: float64

# %% [markdown]
# - Plot credit score binned

# %%
# set binned credit score
bins7 = list(np.arange(350, 851, 25))

aux7_1['credit_binned'] = pd.cut(aux7_1['credit_score'], bins=bins7)

plt.subplots(figsize=(12,6))

sns.countplot(x='credit_binned', data=aux7_1).set_title("credit score per group of 25 of clients not in churn");
# rotate x axis
plt.xticks(rotation=90);

# %%
 aux7_2['credit_binned'] = pd.cut(aux7_2['credit_score'], bins=bins7)

plt.subplots(figsize=(12,6))

sns.countplot(x='credit_binned', data=aux7_2).set_title("credit score per group of 25 of clients in churn");
# rotate x axis
plt.xticks(rotation=90);

# %% [markdown]
# - Calculate the relative percentage of clients in churn and not in churn per credit score.

# %%
# create new dataframe
aux700 = df4[['credit_score', 'exited']]
aux700['credit_binned'] = pd.cut(aux700['credit_score'], bins=bins7)

# new dataframe with credit_binned, exited and number of clients
aux701 = aux700[['credit_binned', 'credit_score', 'exited']].\
groupby(['credit_binned', 'exited']).count().reset_index()

# rename new dataframe columns
aux701.columns = ['credit_binned', 'exited', 'clients']

# sum of clients in churn
clients_in_churn = aux701[aux701['exited'] == 1]['clients'].sum()

# sum of clients not in churn
clients_not_churn = aux701[aux701['exited'] == 0]['clients'].sum()

# calculate the relative percentage of clients in churn and not in churn
aux701['relative_percentage'] = aux701.\
apply(lambda x: ((x['clients'] / clients_in_churn)*100) if x['exited'] == 1 else ((x['clients'] / clients_not_churn)*100), axis=1)

aux701
# Out:
#    credit_binned  exited  clients  relative_percentage
# 0     (350, 375]   False        0                0.000
# 1     (350, 375]    True        6                0.369
# 2     (375, 400]   False        0                0.000
# 3     (375, 400]    True        5                0.308
# 4     (400, 425]   False       30                0.471
# 5     (400, 425]    True       13                0.800
# 6     (425, 450]   False       72                1.130
# 7     (425, 450]    True       23                1.415
# 8     (450, 475]   False      106                1.664
# 9     (450, 475]    True       24                1.476
# 10    (475, 500]   False      181                2.841
# 11    (475, 500]    True       51                3.137
# 12    (500, 525]   False      265                4.160
# 13    (500, 525]    True       74                4.551
# 14    (525, 550]   False      335                5.259
# 15    (525, 550]    True      104                6.396
# 16    (550, 575]   False      390                6.122
# 17    (550, 575]    True      100                6.150
# 18    (575, 600]   False      530                8.320
# 19    (575, 600]    True      131                8.057
# 20    (600, 625]   False      557                8.744
# 21    (600, 625]    True      150                9.225
# 22    (625, 650]   False      619                9.717
# 23    (625, 650]    True      166               10.209
# 24    (650, 675]   False      624                9.796
# 25    (650, 675]    True      143                8.795
# 26    (675, 700]   False      656               10.298
# 27    (675, 700]    True      148                9.102
# 28    (700, 725]   False      561                8.807
# 29    (700, 725]    True      121                7.442
# 30    (725, 750]   False      416                6.531
# 31    (725, 750]    True      118                7.257
# 32    (750, 775]   False      353                5.542
# 33    (750, 775]    True       92                5.658
# 34    (775, 800]   False      258                4.050
# 35    (775, 800]    True       57                3.506
# 36    (800, 825]   False      162                2.543
# 37    (800, 825]    True       41                2.522
# 38    (825, 850]   False      255                4.003
# 39    (825, 850]    True       59                3.629

# %% [markdown]
# - Plot the relative percentage of clients in churn and not in churn per credit score.

# %%
plt.subplots(figsize=(16,8))
sns.barplot(x='credit_binned', y='relative_percentage', hue='exited', data=aux701).\
set_title("Credit score groups' relative percentage with respect to churn");
plt.xticks(rotation=90);
save_fig('04_credit_score_relative_percentage')
# Out:
# Saving figure 04_credit_score_relative_percentage

# %%
 # point-biserial correlation coefficient heatmap function. For details, please see section 0.2. Helper Functions.
point_bi_corr(df4[['exited']], df4[['credit_score']]);

# %% [markdown]
# - Credit score x age scatterplot

# %%
 plt.subplots(figsize=(12,6))
sns.scatterplot(x='credit_score', y='age',hue='exited', data=df4);

# %% [markdown]
# - The credit score density distribution shows that the distributions for churn and not churn clients are very similar. For credit score below 650 the churn proportion (orange) is greater than the not churn proportion (blue).
# - The relative percentage barplot shows that for credit score greater than 650 the proportion of not churn is greater than the not churn in almost all credit score divisions.
# - The correlation heatmap shows a corefficient between credit score and churn (exited) of -0.034.
# - The credit score x cred_age scatterplot shows a slight churn pattern for cred_age below 20.
# - The credit score x age scatterplot shows a slight churn pattern for age above 45.
# - Therefore, the hypothesis is True: Churn occur for clients with a low credit score.

# %% [markdown]
# **Additional scatterplots**

# %% [markdown]
# - Credit score x balance scatterplot

# %%
plt.subplots(figsize=(12,6))
sns.scatterplot(x='credit_score', y='balance',hue='exited', data=df4);

# %% [markdown]
# - Credit score x estimated salary scatterplot

# %%
 plt.subplots(figsize=(12,6))
sns.scatterplot(x='credit_score', y='estimated_salary',hue='exited', data=df4);

# %% [markdown]
# - Credit score x amount scatterplot

# %%
df4.head()
# Out:
#    credit_score geography  gender  age  tenure    balance  num_of_products  \
# 0           753    France    Male   57       7      0.000                1
# 1           739   Germany    Male   32       3 102128.270                1
# 2           755   Germany  Female   37       0 113865.230                2
# 3           561    France    Male   37       5      0.000                2
# 4           692   Germany    Male   49       6 110540.430                2
#
#    has_cr_card  is_active_member  estimated_salary  exited  balance_age  \
# 0         True             False        159475.080    True    66850.307
# 1         True             False         63981.370    True    74442.503
# 2         True              True        117396.250   False    81022.099
# 3         True             False         83093.250   False    81022.099
# 4        False              True        107472.990   False    81584.674
#
#    balance_per_country       LTV  estimated_salary_per_gender
# 0            61798.897 74836.357                    98967.535
# 1           119481.504 76360.322                    98967.535
# 2           119481.504 81060.026                   100657.602
# 3            61798.897 77666.392                    98967.535
# 4           119481.504 74443.636                    98967.535

# %% [markdown]
# ## H6. Churn rate should be higher among young clients

# %% [markdown]
# **FALSE** Churn rate is lower among young clients.

# %%
 # set dataframes for exited = 0 and exited = 1
aux9_1 = df4[df4['exited']==0]
aux9_2 = df4[df4['exited']==1]

# set up figure size
plt.subplots(figsize=(12,6))

sns.distplot(aux9_1['age'], label='not churn');
sns.distplot(aux9_2['age'], color='orange', label='churn');
plt.title('Age density distribution');
plt.legend();
save_fig('04_age_density_distribution')
# Out:
# Saving figure 04_age_density_distribution

# %%
 # plot percentages

# set up figure size
plt.subplots(figsize=(16,8))

# 1st plot: age distribution of clients not in churn
plt.subplot(2,1,1)
age_perc_not_churn = aux9_1['age'].value_counts(normalize=True)*100
sns.barplot(x=age_perc_not_churn.index, y=age_perc_not_churn).\
set_title('age distribution of clients not in churn');
plt.ylabel('age_%');

# 2nd plot: age distribution of clients in churn
plt.subplot(2,1,2)
age_perc_churn = aux9_2['age'].value_counts(normalize=True)*100
sns.barplot(x=age_perc_churn.index, y=age_perc_churn).\
set_title('age distribution of clients in churn');
plt.ylabel('age_%');

save_fig('04_age_percentage_distribution')
# Out:
# Saving figure 04_age_percentage_distribution

# %%
# new dataframe with has_cr_card, exited and number of clients
aux900 = df4[['age','balance', 'exited']].groupby(['age', 'exited']).count().reset_index()
aux900.columns = ['age', 'exited', 'num_clients']

# sum of clients in churn
sum_churn = aux900[aux900['exited']==1]['num_clients'].sum()

# sum of clients not in churn
sum_not_churn = aux900[aux900['exited']==0]['num_clients'].sum()

# calculate relative percentage
aux900['relative_percentage'] = aux900.\
apply(lambda x: ((x['num_clients'] / sum_churn)*100) if x['exited'] == 1 else ((x['num_clients'] / sum_not_churn)*100), axis=1)

aux900
# Out:
#      age  exited  num_clients  relative_percentage
# 0     18   False           16                0.251
# 1     18    True            1                0.061
# 2     19   False           20                0.314
# 3     20   False           31                0.487
# 4     20    True            2                0.123
# ..   ...     ...          ...                  ...
# 121   83   False            1                0.016
# 122   84   False            1                0.016
# 123   84    True            1                0.061
# 124   88   False            1                0.016
# 125   92   False            2                0.031
#
# [126 rows x 4 columns]

# %% [markdown]
# - Plot age relative percentage

# %%
# set up figure size
plt.subplots(figsize=(18,6))

sns.barplot(x='age', y='relative_percentage', hue='exited', data=aux900).\
set_title('Age relative percentage');
save_fig('04_age_relative_percentage')
# Out:
# Saving figure 04_age_relative_percentage

# %%
# point-biserial correlation coefficient heatmap function. For details, please see section 0.2. Helper Functions.
point_bi_corr(df4[['exited']], df4[['age']]);

# %% [markdown]
# - The density distribution plot shows that churn is proportionaly greater from 40 year on.
# - The relative percentage barplot shows that from 40 years until 65 years, the churn ration is greater than the not churn.
# - For all other ages, the not churn proportion is greater.The correlation heatmap shows a correlation coefficient of 0.28.
# - Therefore, the hypothesis is False: churn rate is lower among young clients.

# %% [markdown]
# # 5.0. Data Preparation

# %%
df5 = df4.copy()

# %%
df5.columns
# Out:
# Index(['credit_score', 'geography', 'gender', 'age', 'tenure', 'balance',
#        'num_of_products', 'has_cr_card', 'is_active_member',
#        'estimated_salary', 'exited', 'balance_age', 'balance_per_country',
#        'LTV', 'estimated_salary_per_gender'],
#       dtype='object')

# %%
df5.exited = df4.exited.astype('int64')
df5.has_cr_card = df4.has_cr_card.astype('int64')
df5.is_active_member= df4.is_active_member.astype('int64')

# %% [markdown]
# ## 5.1. Rescaling

# %%
mms = pp.MinMaxScaler()
rbs = pp.RobustScaler()

# age
df5['age'] = rbs.fit_transform(df5[['age']].values)
# save scaler, so it can be applied in new data
with open('../src/features/age.pkl', 'wb') as f:
    pickle.dump(rbs, f)

# Balance
df5['tenure'] = mms.fit_transform(df5[['tenure']].values)
# save scaler, so it can be applied in new data
with open('../src/features/tenure.pkl', 'wb') as f:
    pickle.dump(mms, f)

# balance_age
df5['balance_age'] = mms.fit_transform(df5[['balance_age']].values)
# save scaler, so it can be applied in new data
with open('../src/features/balance_age.pkl', 'wb') as f:
    pickle.dump(mms, f)

# balance_per_country
df5['balance_per_country'] = mms.fit_transform(df5[['balance_per_country']].values)
# save scaler, so it can be applied in new data
with open('../src/features/balance_per_country.pkl', 'wb') as f:
    pickle.dump(mms, f)

# LTV
df5['LTV'] = mms.fit_transform(df5[['LTV']].values)
# save scaler, so it can be applied in new data
with open('../src/features/LTV.pkl', 'wb') as f:
    pickle.dump(mms, f)

# estimated_salary_per_gender
df5['estimated_salary_per_gender'] = mms.fit_transform(df5[['estimated_salary_per_gender']].values)
# save scaler, so it can be applied in new data
with open('../src/features/estimated_salary_per_gender.pkl', 'wb') as f:
    pickle.dump(mms, f)

#EstimatedSalary
df5['estimated_salary'] = mms.fit_transform(df5[['estimated_salary']].values)
# save scaler, so it can be applied in new data
with open('../src/features/estimated_salary.pkl', 'wb') as f:
    pickle.dump(mms, f)

# %% [markdown]
# ## 5.2. Encoding

# %%
# #gender - label encoding 
# gender_dict = { 'Male':0 , 'Female':1 }
# df5['gender'] = df5['gender'].map( gender_dict ) 

#Geography/gender - One Hot Encoding
# one hot encoding encoding 
df5 = pd.get_dummies(df5, prefix=['country'], columns=['geography'])
df5 = pd.get_dummies(df5, prefix=['gender'], columns=['gender'])

# questions_encoding = {'False': 0,'True': 1}

# df5['is_active_member'] = df5['is_active_member'].map(questions_encoding )
# df5['has_cr_card'] = df5['has_cr_card'].map(questions_encoding)
# df5['exited'] = df5['exited'].map(questions_encoding)

# %%
df5.isna().sum()
# Out:
# credit_score                   0
# age                            0
# tenure                         0
# balance                        0
# num_of_products                0
# has_cr_card                    0
# is_active_member               0
# estimated_salary               0
# exited                         0
# balance_age                    0
# balance_per_country            0
# LTV                            0
# estimated_salary_per_gender    0
# country_France                 0
# country_Germany                0
# country_Spain                  0
# gender_Female                  0
# gender_Male                    0
# dtype: int64

# %%
df5.head()
# Out:
#    credit_score    age  tenure    balance  num_of_products  has_cr_card  \
# 0           753  1.667   0.700      0.000                1            1
# 1           739 -0.417   0.300 102128.270                1            1
# 2           755  0.000   0.000 113865.230                2            1
# 3           561  0.000   0.500      0.000                2            1
# 4           692  1.000   0.600 110540.430                2            0
#
#    is_active_member  estimated_salary  exited  balance_age  \
# 0                 0             0.797       1        0.540
# 1                 0             0.320       1        0.601
# 2                 1             0.587       0        0.654
# 3                 0             0.415       0        0.654
# 4                 1             0.537       0        0.659
#
#    balance_per_country   LTV  estimated_salary_per_gender  country_France  \
# 0                0.000 0.203                        0.000               1
# 1                1.000 0.398                        0.000               0
# 2                1.000 1.000                        1.000               0
# 3                0.000 0.565                        0.000               1
# 4                1.000 0.153                        0.000               0
#
#    country_Germany  country_Spain  gender_Female  gender_Male
# 0                0              0              0            1
# 1                1              0              0            1
# 2                1              0              1            0
# 3                0              0              0            1
# 4                1              0              0            1

# %% [markdown]
# # 6.0. Feature Selection

# %%
 # Remove target variable from train set
X_train = df5.drop(['exited','balance'], axis=1)

# target variable
y_train = df5['exited'].copy()

# %%
X_train.head()
# Out:
#    credit_score    age  tenure  num_of_products  has_cr_card  \
# 0           753  1.667   0.700                1            1
# 1           739 -0.417   0.300                1            1
# 2           755  0.000   0.000                2            1
# 3           561  0.000   0.500                2            1
# 4           692  1.000   0.600                2            0
#
#    is_active_member  estimated_salary  balance_age  balance_per_country   LTV  \
# 0                 0             0.797        0.540                0.000 0.203
# 1                 0             0.320        0.601                1.000 0.398
# 2                 1             0.587        0.654                1.000 1.000
# 3                 0             0.415        0.654                0.000 0.565
# 4                 1             0.537        0.659                1.000 0.153
#
#    estimated_salary_per_gender  country_France  country_Germany  \
# 0                        0.000               1                0
# 1                        0.000               0                1
# 2                        1.000               0                1
# 3                        0.000               1                0
# 4                        0.000               0                1
#
#    country_Spain  gender_Female  gender_Male
# 0              0              0            1
# 1              0              0            1
# 2              0              1            0
# 3              0              0            1
# 4              0              0            1

# %% [markdown]
# ## 6.1. Random Forest as Feature Selector

# %%
X_train.head()
# Out:
#    credit_score    age  tenure  num_of_products  has_cr_card  \
# 0           753  1.667   0.700                1            1
# 1           739 -0.417   0.300                1            1
# 2           755  0.000   0.000                2            1
# 3           561  0.000   0.500                2            1
# 4           692  1.000   0.600                2            0
#
#    is_active_member  estimated_salary  balance_age  balance_per_country   LTV  \
# 0                 0             0.797        0.540                0.000 0.203
# 1                 0             0.320        0.601                1.000 0.398
# 2                 1             0.587        0.654                1.000 1.000
# 3                 0             0.415        0.654                0.000 0.565
# 4                 1             0.537        0.659                1.000 0.153
#
#    estimated_salary_per_gender  country_France  country_Germany  \
# 0                        0.000               1                0
# 1                        0.000               0                1
# 2                        1.000               0                1
# 3                        0.000               1                0
# 4                        0.000               0                1
#
#    country_Spain  gender_Female  gender_Male
# 0              0              0            1
# 1              0              0            1
# 2              0              1            0
# 3              0              0            1
# 4              0              0            1

# %%
 # train random forest classifier
rf = RandomForestClassifier(random_state=42)
rf.fit(X_train, y_train)

# feature importance data frame
feat_imp = pd.DataFrame({'feature': X_train.columns,
                        'feature_importance': rf.feature_importances_})\
                        .sort_values('feature_importance', ascending=False)\
                        .reset_index(drop=True)


# plot feature importance
plt.subplots(figsize=(12,6))
sns.barplot(x='feature_importance', y='feature', data=feat_imp, orient='h', color='royalblue')\
    .set_title('Feature Importance');

# %%
feat_imp_select = feat_imp.iloc[:13]
feat_imp_select
# Out:
#                 feature  feature_importance
# 0                   age               0.191
# 1      estimated_salary               0.157
# 2          credit_score               0.154
# 3       num_of_products               0.123
# 4           balance_age               0.102
# 5                   LTV               0.066
# 6                tenure               0.066
# 7      is_active_member               0.046
# 8           has_cr_card               0.023
# 9   balance_per_country               0.020
# 10      country_Germany               0.014
# 11       country_France               0.008
# 12          gender_Male               0.008

# %% [markdown]
# - Select top features list.
# - Add geography and is_active_member based on EDA.

# %%
 # top features list
feat_list = feat_imp_select['feature'].to_list() + ['country_Spain', 'gender_Female']
feat_list
# Out:
# ['age',
#  'estimated_salary',
#  'credit_score',
#  'num_of_products',
#  'balance_age',
#  'LTV',
#  'tenure',
#  'is_active_member',
#  'has_cr_card',
#  'balance_per_country',
#  'country_Germany',
#  'country_France',
#  'gender_Male',
#  'country_Spain',
#  'gender_Female']

# %%
# train data with selected features of Feature Selection
x_train = X_train[feat_list]

# %%
x_train.head()
# Out:
#      age  estimated_salary  credit_score  num_of_products  balance_age   LTV  \
# 0  1.667             0.797           753                1        0.540 0.203
# 1 -0.417             0.320           739                1        0.601 0.398
# 2  0.000             0.587           755                2        0.654 1.000
# 3  0.000             0.415           561                2        0.654 0.565
# 4  1.000             0.537           692                2        0.659 0.153
#
#    tenure  is_active_member  has_cr_card  balance_per_country  \
# 0   0.700                 0            1                0.000
# 1   0.300                 0            1                1.000
# 2   0.000                 1            1                1.000
# 3   0.500                 0            1                0.000
# 4   0.600                 1            0                1.000
#
#    country_Germany  country_France  gender_Male  country_Spain  gender_Female
# 0                0               1            1              0              0
# 1                1               0            1              0              0
# 2                1               0            0              0              1
# 3                0               1            1              0              0
# 4                1               0            1              0              0

# %% [markdown]
# ## 5.3. Balanicing Data Set

# %%
# set the resampler
resampler = SMOTETomek(random_state=42, n_jobs=-1)

# resample the dataset
x_balanced, y_balanced = resampler.fit_resample(x_train, y_train)

# %%
total_churn = y_train.sum()
churn_ratio = total_churn / len(y_train)

print(f'The total churn rate in the training data set is {100.*churn_ratio:.2f}%')
# Out:
# The total churn rate in the training data set is 20.38%

# %%
 # plots before and after SMOTETomek
plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
sns.countplot(x=y_train)
plt.title("Before SMOTE")

plt.subplot(1,2,2)
sns.countplot(x=y_balanced)
plt.title("After SMOTE")

plt.show()

# %% [markdown]
# ### Column Transformer for Pipeline

# %%
# cols_norm = ['age']
# scaler = pp.StandardScaler()

# cols_mms = ['credit_score', 'tenure', 'salary', 'balance_age','balance_per_country','LTV','estimated_salary_per_gender']
# mms = pp.MinMaxScaler()


# cols_ohe = ['geography', 'gender']
# ohe = OneHotEncoder(drop='if_binary')

# ct = make_column_transformer((scaler, cols_norm), (mms, cols_mms), (ohe, cols_ohe), remainder='passthrough')

# model_cols = ['age', 'credit_score', 'tenure', 'salary', 'france', 'germany', 'spain',
#               'gender', 'num_products', 'credit_card', 'active_member']

# %% [markdown]
# # 7.0. Machine Learning Modelling

# %% [markdown]
# ## 7.1. Logistic Regression

# %%
# instantiate the model
logit = LogisticRegression()

# fit the model
logit.fit(x_balanced, y_balanced)

# model performance with performance function. For more details, please see Helper Functions section.
logit_performance_bal = performance(logit, x_balanced, y_balanced)
logit_performance_bal
# Out:
#    test_accuracy  test_precision  test_recall  test_f1_score  \
# 0          0.805           0.831        0.758          0.785
#
#    test_roc_auc_score  test_mcc
# 0               0.805     0.618

# %% [markdown]
# ## 7.2. Random Forest

# %%
rf = RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=None,
                            min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0,
                            max_features='auto', max_leaf_nodes=None, min_impurity_decrease=0.0,
                            bootstrap=True, oob_score=False, n_jobs=-1,
                            random_state=42, verbose=0, warm_start=False, class_weight=None,
                            ccp_alpha=0.0, max_samples=None)
rf.fit(x_balanced, y_balanced)

# model performance with performance function. For more details, please see Helper Functions section.
rf_performance_bal = performance(rf, x_balanced, y_balanced)
rf_performance_bal
# Out:
#    test_accuracy  test_precision  test_recall  test_f1_score  \
# 0          0.892           0.915        0.862          0.879
#
#    test_roc_auc_score  test_mcc
# 0               0.892     0.795

# %% [markdown]
# ## 7.3. Support Vector Machine - SVM

# %%
svm = SVC(random_state=42, probability=True)

svm.fit(x_balanced, y_balanced)

# model performance with performance function. For more details, please see Helper Functions section.
svm_performance_bal = performance(svm, x_balanced, y_balanced)
svm_performance_bal
# Out:
#    test_accuracy  test_precision  test_recall  test_f1_score  \
# 0          0.516           0.555        0.169          0.259
#
#    test_roc_auc_score  test_mcc
# 0               0.516     0.046

# %% [markdown]
# ## 7.4. XGBoost

# %%
xgb = XGBClassifier(random_state=42)

# xgb.fit(x_balanced, y_balanced,
#         eval_metric='logloss',
#         early_stopping_rounds=10,
#         eval_set=[(x_balanced, y_balanced)],
#        )

xgb.fit(x_balanced, y_balanced)

# model performance with performance function. For more details, please see Helper Functions section.
xgb_performance_bal = performance(xgb, x_balanced, y_balanced)
xgb_performance_bal
# Out:
# [13:53:55] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117766796/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:53:55] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117766796/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:53:56] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117766796/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:53:56] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117766796/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:53:56] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117766796/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:53:57] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117766796/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:53:57] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117766796/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:53:58] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117766796/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:53:58] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117766796/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:53:58] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117766796/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:53:59] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117766796/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#    test_accuracy  test_precision  test_recall  test_f1_score  \
# 0          0.897           0.929        0.858          0.876
#
#    test_roc_auc_score  test_mcc
# 0               0.897     0.810

# %% [markdown]
# ## 7.5. Performance Comparison

# %%
# performance comparison data frame
performance_comp = pd.concat([logit_performance_bal, rf_performance_bal,svm_performance_bal, xgb_performance_bal])
performance_comp.columns = ['accuracy', 'precision', 'recall', 'f1_score', 'roc_auc_score', 'MCC']
performance_comp['model'] = ['Logistic Regression', 'Random Forest','SVC', 'XGBoost']
performance_comp = performance_comp[['model', 'accuracy', 'precision', 'recall', 'f1_score', 'roc_auc_score', 'MCC']]
performance_comp.set_index('model')
# Out:
#                      accuracy  precision  recall  f1_score  roc_auc_score  \
# model
# Logistic Regression     0.805      0.831   0.758     0.785          0.805
# Random Forest           0.892      0.915   0.862     0.879          0.892
# SVC                     0.516      0.555   0.169     0.259          0.516
# XGBoost                 0.897      0.929   0.858     0.876          0.897
#
#                       MCC
# model
# Logistic Regression 0.618
# Random Forest       0.795
# SVC                 0.046
# XGBoost             0.810

# %% [markdown]
# - Metrics calculated with 10-fold cross validation.
# - Best models are Random Forest and XGBoost.
# - XGBoost has the best Precision (93.5%) and best MCC (81.5%).
#
# Based on the Business context and in order to better accomplish the project goals, deliverables and deployment, the chosen model is XGBoost.

# %% [markdown]
# # 8.0. Hyperparameter Fine-Tuning

# %% [markdown]
# ## 8.1. Prepare Test Set

# %%
test_set.sample(5)
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 5778       5779    15640377  Goloubev          526    France  Female   36
# 4399       4400    15572547   Vaguine          670    France  Female   45
# 9945       9946    15674000  Cattaneo          645    France    Male   44
# 2535       2536    15578809       Hao          651   Germany    Male   40
# 8868       8869    15708357   Chapman          649     Spain  Female   38
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 5778       0      0.000              2          1               0
# 4399       9 104930.380              1          1               0
# 9945      10      0.000              2          0               1
# 2535       1 134760.210              2          0               0
# 8868       8      0.000              1          1               0
#
#       EstimatedSalary  Exited
# 5778        97767.630       0
# 4399       155921.810       1
# 9945       166707.220       0
# 2535       174434.060       1
# 8868       103760.530       0

# %%
test_set_ = test_set.copy()

# %%
# rename columns
test_set_ = rename_columns(test_set_)

# Create new features
test_set_ = feature_engineering(test_set_)

test_set_.head()
# Out:
#    row_number  customer_id    surname  credit_score geography  gender  age  \
# 0        5703     15749540     Hsiung           585    France    Male   36
# 1        3668     15807340  O'Donnell           525   Germany    Male   33
# 2        1618     15801062   Matthews           557     Spain  Female   40
# 3        5674     15572801  Krischock           639     Spain    Male   34
# 4        4273     15600708  Calabresi           640     Spain  Female   34
#
#    tenure  num_of_products  has_cr_card  is_active_member  estimated_salary  \
# 0       7                2            1                 0         94283.090
# 1       4                2            0                 0         55072.930
# 2       4                2            0                 1        105433.530
# 3       5                2            0                 0         33950.080
# 4       3                1            1                 1        168544.850
#
#    exited  balance_age  balance_per_country       LTV  \
# 0       0    83660.840            63241.416 78354.564
# 1       0    74783.138           120719.137 77396.481
# 2       0    82075.146            59783.794 77396.481
# 3       0    74842.036            59783.794 71832.542
# 4       0    74842.036            59783.794 83570.744
#
#    estimated_salary_per_gender
# 0                   102522.448
# 1                   102522.448
# 2                   100383.749
# 3                   102522.448
# 4                   100383.749

# %%
test_set_.columns
# Out:
# Index(['row_number', 'customer_id', 'surname', 'credit_score', 'geography',
#        'gender', 'age', 'tenure', 'num_of_products', 'has_cr_card',
#        'is_active_member', 'estimated_salary', 'exited', 'balance_age',
#        'balance_per_country', 'LTV', 'estimated_salary_per_gender'],
#       dtype='object')

# %%
# copy test_set
X_test_prep = test_set_.copy()

# %%
# Transformations
# Load scalers
age_scaler                         = pickle.load(open('../src/features/age.pkl', 'rb'))
tenure_scaler                      = pickle.load(open('../src/features/tenure.pkl', 'rb'))
balance_age_scaler                 = pickle.load(open('../src/features/balance_age.pkl', 'rb'))
balance_per_country_scaler         = pickle.load(open('../src/features/balance_per_country.pkl', 'rb'))
estimated_salary_per_gender_scaler = pickle.load(open('../src/features/estimated_salary_per_gender.pkl', 'rb'))
estimated_salary_scaler            = pickle.load(open('../src/features/estimated_salary.pkl', 'rb'))
LTV_scaler                         = pickle.load(open('../src/features/LTV.pkl', 'rb'))

# %%
# Apply rescaling
X_test_prep['age']                         = age_scaler.fit_transform(X_test_prep[['age']].values)
X_test_prep['tenure']                      = tenure_scaler.fit_transform(X_test_prep[['tenure']].values)
X_test_prep['balance_age']                 = balance_age_scaler.fit_transform(X_test_prep[['balance_age']].values)
X_test_prep['balance_per_country']         = balance_per_country_scaler.fit_transform(X_test_prep[['balance_per_country']].values)
X_test_prep['estimated_salary_per_gender'] = estimated_salary_per_gender_scaler.fit_transform(X_test_prep[['estimated_salary_per_gender']].values)
X_test_prep['estimated_salary']            = estimated_salary_scaler.fit_transform(X_test_prep[['estimated_salary']].values)
X_test_prep['LTV']                         = LTV_scaler.fit_transform(X_test_prep[['LTV']].values)

# %%
# Encoding - apply one-hot encoding
X_test_prep = pd.get_dummies(X_test_prep, prefix=['country'], columns=['geography'])
X_test_prep = pd.get_dummies(X_test_prep, prefix=['gender'], columns=['gender'])

# %%
# target variable
y_test = X_test_prep['exited'].copy()

# %%
# selected feeatures list
select_feat = ['age',
 'estimated_salary',
 'credit_score',
 'num_of_products',
 'balance_age',
 'LTV',
 'tenure',
 'is_active_member',
 'has_cr_card',
 'balance_per_country',
 'country_Germany',
 'country_France',
 'gender_Male',
 'country_Spain',
 'gender_Female']

# selected features on test set
x_test = X_test_prep[select_feat]

# %%
x_test.head()
# Out:
#      age  estimated_salary  credit_score  num_of_products  balance_age   LTV  \
# 0 -0.083             0.471           585                2        0.593 0.702
# 1 -0.333             0.275           525                2        0.530 0.647
# 2  0.250             0.527           557                2        0.582 0.647
# 3 -0.250             0.169           639                2        0.531 0.330
# 4 -0.250             0.843           640                1        0.531 1.000
#
#    tenure  is_active_member  has_cr_card  balance_per_country  \
# 0   0.700                 0            1                0.057
# 1   0.400                 0            0                1.000
# 2   0.400                 1            0                0.000
# 3   0.500                 0            0                0.000
# 4   0.300                 1            1                0.000
#
#    country_Germany  country_France  gender_Male  country_Spain  gender_Female
# 0                0               1            1              0              0
# 1                1               0            1              0              0
# 2                0               0            0              1              1
# 3                0               0            1              1              0
# 4                0               0            0              1              1

# %% [markdown]
# ## 8.2. Bayesian Optimization with HYPEROPT

# %%
space={'max_depth': hp.quniform("max_depth", 3, 18, 1),
        'gamma': hp.uniform ('gamma', 1,9),
        'reg_alpha' : hp.quniform('reg_alpha', 40,180,1),
        'reg_lambda' : hp.uniform('reg_lambda', 0,1),
        'colsample_bytree' : hp.uniform('colsample_bytree', 0.5,1),
        'min_child_weight' : hp.quniform('min_child_weight', 0, 10, 1),
        'n_estimators': 180,
        'seed': 0
    }

# %% [markdown]
# ### 8.2.1. Define objective function ¶

# %%
def objective(space):
    
    clf=XGBClassifier(
                    n_estimators =space['n_estimators'], max_depth = int(space['max_depth']), gamma = space['gamma'],
                    reg_alpha = int(space['reg_alpha']),min_child_weight=int(space['min_child_weight']),
                    colsample_bytree=int(space['colsample_bytree']))
    
    evaluation = [(x_balanced, y_balanced), (x_test , y_test)]
    
    clf.fit(x_balanced, y_balanced,
            eval_set=evaluation, 
            eval_metric="auc",
            early_stopping_rounds=10)
    

    # predictions
    xgb_y_pred = clf.predict(x_test)
    accuracy = precision_score(y_test, xgb_y_pred)
    print ("SCORE:", accuracy)
    return {'loss': -accuracy, 'status': STATUS_OK }

# %% [markdown]
# ### 8.2.2. Optimization algorithm ¶

# %%
trials = Trials()

best_hyperparams = fmin(fn = objective,
                        space = space,
                        algo = tpe.suggest,
                        max_evals = 100,
                        trials = trials)
# Out:
# [0]	validation_0-auc:0.82755	validation_1-auc:0.50156
# [1]	validation_0-auc:0.85340	validation_1-auc:0.52449
# [2]	validation_0-auc:0.89903	validation_1-auc:0.69559
# [3]	validation_0-auc:0.89903	validation_1-auc:0.69559
# [4]	validation_0-auc:0.89044	validation_1-auc:0.68993
# [5]	validation_0-auc:0.91180	validation_1-auc:0.69164
# [6]	validation_0-auc:0.91599	validation_1-auc:0.69617
# [7]	validation_0-auc:0.91225	validation_1-auc:0.69020
# [8]	validation_0-auc:0.92188	validation_1-auc:0.70552
# [9]	validation_0-auc:0.92578	validation_1-auc:0.71657
# [10]	validation_0-auc:0.92595	validation_1-auc:0.72271
# [11]	validation_0-auc:0.92359	validation_1-auc:0.71738
# [12]	validation_0-auc:0.93106	validation_1-auc:0.74159
# [13]	validation_0-auc:0.93131	validation_1-auc:0.71951
# [14]	validation_0-auc:0.93154	validation_1-auc:0.71851
# [15]	validation_0-auc:0.93139	validation_1-auc:0.71715
# [16]	validation_0-auc:0.93139	validation_1-auc:0.71715
# [17]	validation_0-auc:0.93380	validation_1-auc:0.72335
# [18]	validation_0-auc:0.93383	validation_1-auc:0.70213
# [19]	validation_0-auc:0.93368	validation_1-auc:0.70470
# [20]	validation_0-auc:0.93431	validation_1-auc:0.73589
# [21]	validation_0-auc:0.93446	validation_1-auc:0.73499
# SCORE:
# 0.39123630672926446
# [0]	validation_0-auc:0.67499	validation_1-auc:0.51070
# [1]	validation_0-auc:0.72216	validation_1-auc:0.54400
# [2]	validation_0-auc:0.82973	validation_1-auc:0.72557
# [3]	validation_0-auc:0.82973	validation_1-auc:0.72557
# [4]	validation_0-auc:0.82284	validation_1-auc:0.70793
# [5]	validation_0-auc:0.83442	validation_1-auc:0.70837
# [6]	validation_0-auc:0.83571	validation_1-auc:0.70152
# [7]	validation_0-auc:0.82553	validation_1-auc:0.69239
# [8]	validation_0-auc:0.85186	validation_1-auc:0.71130
# [9]	validation_0-auc:0.86462	validation_1-auc:0.72331
# [10]	validation_0-auc:0.86305	validation_1-auc:0.72991
# [11]	validation_0-auc:0.85762	validation_1-auc:0.72255
# [12]	validation_0-auc:0.87962	validation_1-auc:0.74661
# [13]	validation_0-auc:0.88791	validation_1-auc:0.74085
# [14]	validation_0-auc:0.88940	validation_1-auc:0.74038
# [15]	validation_0-auc:0.88948	validation_1-auc:0.73776
# [16]	validation_0-auc:0.88948	validation_1-auc:0.73776
# [17]	validation_0-auc:0.89772	validation_1-auc:0.75202
# [18]	validation_0-auc:0.90019	validation_1-auc:0.74357
# [19]	validation_0-auc:0.90036	validation_1-auc:0.74252
# [20]	validation_0-auc:0.89892	validation_1-auc:0.76450
# [21]	validation_0-auc:0.89949	validation_1-auc:0.76181
# [22]	validation_0-auc:0.90240	validation_1-auc:0.75616
# [23]	validation_0-auc:0.90240	validation_1-auc:0.75616
# [24]	validation_0-auc:0.89831	validation_1-auc:0.76589
# [25]	validation_0-auc:0.89852	validation_1-auc:0.76520
# [26]	validation_0-auc:0.89852	validation_1-auc:0.76520
# [27]	validation_0-auc:0.90002	validation_1-auc:0.75774
# [28]	validation_0-auc:0.90002	validation_1-auc:0.75774
# [29]	validation_0-auc:0.91657	validation_1-auc:0.78765
# [30]	validation_0-auc:0.91335	validation_1-auc:0.79023
# [31]	validation_0-auc:0.91335	validation_1-auc:0.79023
# [32]	validation_0-auc:0.91104	validation_1-auc:0.79233
# [33]	validation_0-auc:0.91104	validation_1-auc:0.79233
# [34]	validation_0-auc:0.91104	validation_1-auc:0.79233
# [35]	validation_0-auc:0.91066	validation_1-auc:0.79132
# [36]	validation_0-auc:0.91066	validation_1-auc:0.79132
# [37]	validation_0-auc:0.91066	validation_1-auc:0.79132
# [38]	validation_0-auc:0.91066	validation_1-auc:0.79132
# [39]	validation_0-auc:0.91066	validation_1-auc:0.79132
# [40]	validation_0-auc:0.91066	validation_1-auc:0.79132
# [41]	validation_0-auc:0.91066	validation_1-auc:0.79132
# SCORE:
# 0.3610798650168729
# [0]	validation_0-auc:0.76653	validation_1-auc:0.49298
# [1]	validation_0-auc:0.78831	validation_1-auc:0.53148
# [2]	validation_0-auc:0.85813	validation_1-auc:0.71256
# [3]	validation_0-auc:0.85813	validation_1-auc:0.71256
# [4]	validation_0-auc:0.85146	validation_1-auc:0.69905
# [5]	validation_0-auc:0.86218	validation_1-auc:0.69442
# [6]	validation_0-auc:0.87204	validation_1-auc:0.69688
# [7]	validation_0-auc:0.86240	validation_1-auc:0.69107
# [8]	validation_0-auc:0.88294	validation_1-auc:0.70424
# [9]	validation_0-auc:0.89171	validation_1-auc:0.71488
# [10]	validation_0-auc:0.88871	validation_1-auc:0.72132
# [11]	validation_0-auc:0.88367	validation_1-auc:0.71689
# [12]	validation_0-auc:0.89998	validation_1-auc:0.74210
# [13]	validation_0-auc:0.90297	validation_1-auc:0.72665
# [14]	validation_0-auc:0.90395	validation_1-auc:0.72525
# [15]	validation_0-auc:0.90401	validation_1-auc:0.72396
# [16]	validation_0-auc:0.90401	validation_1-auc:0.72396
# [17]	validation_0-auc:0.90962	validation_1-auc:0.73113
# [18]	validation_0-auc:0.91091	validation_1-auc:0.71213
# [19]	validation_0-auc:0.91097	validation_1-auc:0.71420
# [20]	validation_0-auc:0.90944	validation_1-auc:0.74384
# [21]	validation_0-auc:0.90967	validation_1-auc:0.74271
# [22]	validation_0-auc:0.91171	validation_1-auc:0.73839
# [23]	validation_0-auc:0.91171	validation_1-auc:0.73839
# [24]	validation_0-auc:0.90752	validation_1-auc:0.75172
# [25]	validation_0-auc:0.90759	validation_1-auc:0.75191
# [26]	validation_0-auc:0.90759	validation_1-auc:0.75191
# [27]	validation_0-auc:0.90686	validation_1-auc:0.75153
# [28]	validation_0-auc:0.90686	validation_1-auc:0.75153
# [29]	validation_0-auc:0.92151	validation_1-auc:0.78021
# [30]	validation_0-auc:0.91818	validation_1-auc:0.78372
# [31]	validation_0-auc:0.91818	validation_1-auc:0.78372
# [32]	validation_0-auc:0.91560	validation_1-auc:0.78497
# [33]	validation_0-auc:0.91560	validation_1-auc:0.78497
# [34]	validation_0-auc:0.91560	validation_1-auc:0.78497
# [35]	validation_0-auc:0.91529	validation_1-auc:0.78442
# [36]	validation_0-auc:0.91529	validation_1-auc:0.78442
# [37]	validation_0-auc:0.91529	validation_1-auc:0.78442
# [38]	validation_0-auc:0.91529	validation_1-auc:0.78442
# [39]	validation_0-auc:0.91529	validation_1-auc:0.78442
# [40]	validation_0-auc:0.91529	validation_1-auc:0.78442
# [41]	validation_0-auc:0.91529	validation_1-auc:0.78442
# [42]	validation_0-auc:0.91529	validation_1-auc:0.78442
# SCORE:
# 0.35011185682326623
# [0]	validation_0-auc:0.73556	validation_1-auc:0.50156
# [1]	validation_0-auc:0.75544	validation_1-auc:0.53959
# [2]	validation_0-auc:0.84089	validation_1-auc:0.71973
# [3]	validation_0-auc:0.84089	validation_1-auc:0.71973
# [4]	validation_0-auc:0.83485	validation_1-auc:0.70689
# [5]	validation_0-auc:0.84776	validation_1-auc:0.69936
# [6]	validation_0-auc:0.85010	validation_1-auc:0.69742
# [7]	validation_0-auc:0.84068	validation_1-auc:0.68848
# [8]	validation_0-auc:0.86524	validation_1-auc:0.70517
# [9]	validation_0-auc:0.87623	validation_1-auc:0.71593
# [10]	validation_0-auc:0.87471	validation_1-auc:0.72223
# [11]	validation_0-auc:0.86924	validation_1-auc:0.71647
# [12]	validation_0-auc:0.88868	validation_1-auc:0.74226
# [13]	validation_0-auc:0.89373	validation_1-auc:0.72801
# [14]	validation_0-auc:0.89484	validation_1-auc:0.72705
# [15]	validation_0-auc:0.89498	validation_1-auc:0.72568
# [16]	validation_0-auc:0.89498	validation_1-auc:0.72568
# [17]	validation_0-auc:0.90189	validation_1-auc:0.73383
# [18]	validation_0-auc:0.90546	validation_1-auc:0.71161
# [19]	validation_0-auc:0.90566	validation_1-auc:0.71363
# [20]	validation_0-auc:0.90455	validation_1-auc:0.74265
# [21]	validation_0-auc:0.90524	validation_1-auc:0.74135
# [22]	validation_0-auc:0.90759	validation_1-auc:0.73621
# [23]	validation_0-auc:0.90759	validation_1-auc:0.73621
# [24]	validation_0-auc:0.90354	validation_1-auc:0.75010
# [25]	validation_0-auc:0.90369	validation_1-auc:0.75033
# [26]	validation_0-auc:0.90369	validation_1-auc:0.75033
# [27]	validation_0-auc:0.90503	validation_1-auc:0.74387
# [28]	validation_0-auc:0.90471	validation_1-auc:0.74529
# [29]	validation_0-auc:0.91992	validation_1-auc:0.77507
# [30]	validation_0-auc:0.91710	validation_1-auc:0.78067
# [31]	validation_0-auc:0.91710	validation_1-auc:0.78067
# [32]	validation_0-auc:0.91461	validation_1-auc:0.78243
# [33]	validation_0-auc:0.91461	validation_1-auc:0.78243
# [34]	validation_0-auc:0.91461	validation_1-auc:0.78243
# [35]	validation_0-auc:0.91459	validation_1-auc:0.78210
# [36]	validation_0-auc:0.91440	validation_1-auc:0.78203
# [37]	validation_0-auc:0.91440	validation_1-auc:0.78203
# [38]	validation_0-auc:0.91440	validation_1-auc:0.78203
# [39]	validation_0-auc:0.91440	validation_1-auc:0.78203
# [40]	validation_0-auc:0.91440	validation_1-auc:0.78203
# [41]	validation_0-auc:0.91440	validation_1-auc:0.78203
# SCORE:
# 0.3512304250559284
# [0]	validation_0-auc:0.67499	validation_1-auc:0.51070
# [1]	validation_0-auc:0.72216	validation_1-auc:0.54400
# [2]	validation_0-auc:0.82895	validation_1-auc:0.72548
# [3]	validation_0-auc:0.82895	validation_1-auc:0.72548
# [4]	validation_0-auc:0.82260	validation_1-auc:0.70793
# [5]	validation_0-auc:0.83691	validation_1-auc:0.71077
# [6]	validation_0-auc:0.84241	validation_1-auc:0.70819
# [7]	validation_0-auc:0.83263	validation_1-auc:0.69879
# [8]	validation_0-auc:0.85794	validation_1-auc:0.71657
# [9]	validation_0-auc:0.86929	validation_1-auc:0.72643
# [10]	validation_0-auc:0.86754	validation_1-auc:0.73286
# [11]	validation_0-auc:0.86228	validation_1-auc:0.72540
# [12]	validation_0-auc:0.88316	validation_1-auc:0.74989
# [13]	validation_0-auc:0.89033	validation_1-auc:0.74547
# [14]	validation_0-auc:0.89164	validation_1-auc:0.74481
# [15]	validation_0-auc:0.89172	validation_1-auc:0.74309
# [16]	validation_0-auc:0.89172	validation_1-auc:0.74309
# [17]	validation_0-auc:0.89937	validation_1-auc:0.75786
# [18]	validation_0-auc:0.90116	validation_1-auc:0.74427
# [19]	validation_0-auc:0.90138	validation_1-auc:0.74382
# [20]	validation_0-auc:0.89997	validation_1-auc:0.76480
# [21]	validation_0-auc:0.90068	validation_1-auc:0.76304
# [22]	validation_0-auc:0.90344	validation_1-auc:0.75776
# [23]	validation_0-auc:0.90344	validation_1-auc:0.75776
# [24]	validation_0-auc:0.89925	validation_1-auc:0.76696
# [25]	validation_0-auc:0.89945	validation_1-auc:0.76640
# [26]	validation_0-auc:0.89945	validation_1-auc:0.76640
# [27]	validation_0-auc:0.90090	validation_1-auc:0.75978
# [28]	validation_0-auc:0.90055	validation_1-auc:0.76078
# [29]	validation_0-auc:0.91676	validation_1-auc:0.79073
# [30]	validation_0-auc:0.91361	validation_1-auc:0.79281
# [31]	validation_0-auc:0.91361	validation_1-auc:0.79281
# [32]	validation_0-auc:0.91139	validation_1-auc:0.79461
# [33]	validation_0-auc:0.91139	validation_1-auc:0.79461
# [34]	validation_0-auc:0.91139	validation_1-auc:0.79461
# [35]	validation_0-auc:0.91144	validation_1-auc:0.79410
# [36]	validation_0-auc:0.91144	validation_1-auc:0.79410
# [37]	validation_0-auc:0.91144	validation_1-auc:0.79410
# [38]	validation_0-auc:0.91144	validation_1-auc:0.79410
# [39]	validation_0-auc:0.91144	validation_1-auc:0.79410
# [40]	validation_0-auc:0.91144	validation_1-auc:0.79410
# [41]	validation_0-auc:0.91144	validation_1-auc:0.79410
# SCORE:
# 0.3668639053254438
# [0]	validation_0-auc:0.84608	validation_1-auc:0.50085
# [1]	validation_0-auc:0.87043	validation_1-auc:0.53385
# [2]	validation_0-auc:0.92267	validation_1-auc:0.69502
# [3]	validation_0-auc:0.92279	validation_1-auc:0.69450
# [4]	validation_0-auc:0.91957	validation_1-auc:0.68731
# [5]	validation_0-auc:0.92231	validation_1-auc:0.69131
# [6]	validation_0-auc:0.92157	validation_1-auc:0.69566
# [7]	validation_0-auc:0.91856	validation_1-auc:0.68685
# [8]	validation_0-auc:0.92687	validation_1-auc:0.70543
# [9]	validation_0-auc:0.93028	validation_1-auc:0.71730
# [10]	validation_0-auc:0.93204	validation_1-auc:0.72267
# [11]	validation_0-auc:0.93061	validation_1-auc:0.71830
# [12]	validation_0-auc:0.93660	validation_1-auc:0.74161
# [13]	validation_0-auc:0.93640	validation_1-auc:0.71720
# [14]	validation_0-auc:0.93647	validation_1-auc:0.71584
# [15]	validation_0-auc:0.93626	validation_1-auc:0.71452
# [16]	validation_0-auc:0.93637	validation_1-auc:0.71435
# [17]	validation_0-auc:0.93801	validation_1-auc:0.71973
# [18]	validation_0-auc:0.93786	validation_1-auc:0.69098
# [19]	validation_0-auc:0.93804	validation_1-auc:0.69352
# [20]	validation_0-auc:0.93966	validation_1-auc:0.72352
# [21]	validation_0-auc:0.93968	validation_1-auc:0.72362
# SCORE:
# 0.36857142857142855
# [0]	validation_0-auc:0.73698	validation_1-auc:0.50156
# [1]	validation_0-auc:0.77495	validation_1-auc:0.53936
# [2]	validation_0-auc:0.85486	validation_1-auc:0.71432
# [3]	validation_0-auc:0.85486	validation_1-auc:0.71432
# [4]	validation_0-auc:0.84630	validation_1-auc:0.70144
# [5]	validation_0-auc:0.86469	validation_1-auc:0.69685
# [6]	validation_0-auc:0.87760	validation_1-auc:0.69238
# [7]	validation_0-auc:0.86877	validation_1-auc:0.68710
# [8]	validation_0-auc:0.88821	validation_1-auc:0.70185
# [9]	validation_0-auc:0.89594	validation_1-auc:0.71361
# [10]	validation_0-auc:0.89306	validation_1-auc:0.72029
# [11]	validation_0-auc:0.88818	validation_1-auc:0.71552
# [12]	validation_0-auc:0.90371	validation_1-auc:0.74052
# [13]	validation_0-auc:0.90804	validation_1-auc:0.72477
# [14]	validation_0-auc:0.90886	validation_1-auc:0.72368
# [15]	validation_0-auc:0.90889	validation_1-auc:0.72218
# [16]	validation_0-auc:0.90889	validation_1-auc:0.72218
# [17]	validation_0-auc:0.91396	validation_1-auc:0.72845
# [18]	validation_0-auc:0.91469	validation_1-auc:0.71216
# [19]	validation_0-auc:0.91468	validation_1-auc:0.71484
# [20]	validation_0-auc:0.91349	validation_1-auc:0.74308
# [21]	validation_0-auc:0.91399	validation_1-auc:0.74090
# [22]	validation_0-auc:0.91583	validation_1-auc:0.73525
# [23]	validation_0-auc:0.91583	validation_1-auc:0.73525
# [24]	validation_0-auc:0.91209	validation_1-auc:0.74938
# [25]	validation_0-auc:0.91210	validation_1-auc:0.74970
# [26]	validation_0-auc:0.91210	validation_1-auc:0.74970
# [27]	validation_0-auc:0.91311	validation_1-auc:0.74282
# [28]	validation_0-auc:0.91311	validation_1-auc:0.74282
# [29]	validation_0-auc:0.92736	validation_1-auc:0.77471
# [30]	validation_0-auc:0.92449	validation_1-auc:0.77889
# [31]	validation_0-auc:0.92449	validation_1-auc:0.77889
# [32]	validation_0-auc:0.92233	validation_1-auc:0.78233
# [33]	validation_0-auc:0.92233	validation_1-auc:0.78233
# [34]	validation_0-auc:0.92233	validation_1-auc:0.78233
# [35]	validation_0-auc:0.92195	validation_1-auc:0.78132
# [36]	validation_0-auc:0.92195	validation_1-auc:0.78132
# [37]	validation_0-auc:0.92195	validation_1-auc:0.78132
# [38]	validation_0-auc:0.92195	validation_1-auc:0.78132
# [39]	validation_0-auc:0.92195	validation_1-auc:0.78132
# [40]	validation_0-auc:0.92195	validation_1-auc:0.78132
# [41]	validation_0-auc:0.92195	validation_1-auc:0.78132
# SCORE:
# 0.3207920792079208
# [0]	validation_0-auc:0.84608	validation_1-auc:0.50085
# [1]	validation_0-auc:0.87043	validation_1-auc:0.53038
# [2]	validation_0-auc:0.92225	validation_1-auc:0.69249
# [3]	validation_0-auc:0.92235	validation_1-auc:0.69222
# [4]	validation_0-auc:0.91860	validation_1-auc:0.68428
# [5]	validation_0-auc:0.92181	validation_1-auc:0.68880
# [6]	validation_0-auc:0.92106	validation_1-auc:0.69436
# [7]	validation_0-auc:0.91812	validation_1-auc:0.68658
# [8]	validation_0-auc:0.92645	validation_1-auc:0.70354
# [9]	validation_0-auc:0.92984	validation_1-auc:0.71571
# [10]	validation_0-auc:0.93181	validation_1-auc:0.72135
# [11]	validation_0-auc:0.93031	validation_1-auc:0.71736
# [12]	validation_0-auc:0.93639	validation_1-auc:0.74099
# [13]	validation_0-auc:0.93618	validation_1-auc:0.71681
# [14]	validation_0-auc:0.93627	validation_1-auc:0.71545
# [15]	validation_0-auc:0.93607	validation_1-auc:0.71400
# [16]	validation_0-auc:0.93617	validation_1-auc:0.71372
# [17]	validation_0-auc:0.93785	validation_1-auc:0.71917
# [18]	validation_0-auc:0.93773	validation_1-auc:0.69114
# [19]	validation_0-auc:0.93787	validation_1-auc:0.69403
# [20]	validation_0-auc:0.93946	validation_1-auc:0.72415
# [21]	validation_0-auc:0.93952	validation_1-auc:0.72406
# [22]	validation_0-auc:0.94011	validation_1-auc:0.71573
# SCORE:
# 0.3722627737226277
# [0]	validation_0-auc:0.81864	validation_1-auc:0.50156
# [1]	validation_0-auc:0.84073	validation_1-auc:0.52449
# [2]	validation_0-auc:0.88481	validation_1-auc:0.71063
# [3]	validation_0-auc:0.88481	validation_1-auc:0.71063
# [4]	validation_0-auc:0.87378	validation_1-auc:0.69996
# [5]	validation_0-auc:0.90227	validation_1-auc:0.70225
# [6]	validation_0-auc:0.91097	validation_1-auc:0.70170
# [7]	validation_0-auc:0.90545	validation_1-auc:0.69349
# [8]	validation_0-auc:0.91722	validation_1-auc:0.71133
# [9]	validation_0-auc:0.92181	validation_1-auc:0.72289
# [10]	validation_0-auc:0.92029	validation_1-auc:0.72868
# [11]	validation_0-auc:0.91692	validation_1-auc:0.72356
# [12]	validation_0-auc:0.92605	validation_1-auc:0.74774
# [13]	validation_0-auc:0.92682	validation_1-auc:0.73018
# [14]	validation_0-auc:0.92716	validation_1-auc:0.72872
# [15]	validation_0-auc:0.92710	validation_1-auc:0.72708
# [16]	validation_0-auc:0.92710	validation_1-auc:0.72708
# [17]	validation_0-auc:0.92977	validation_1-auc:0.73517
# [18]	validation_0-auc:0.92979	validation_1-auc:0.71957
# [19]	validation_0-auc:0.92956	validation_1-auc:0.72189
# [20]	validation_0-auc:0.92859	validation_1-auc:0.74941
# [21]	validation_0-auc:0.92882	validation_1-auc:0.74845
# [22]	validation_0-auc:0.92976	validation_1-auc:0.74331
# [23]	validation_0-auc:0.92976	validation_1-auc:0.74331
# [24]	validation_0-auc:0.92644	validation_1-auc:0.75551
# [25]	validation_0-auc:0.92638	validation_1-auc:0.75532
# [26]	validation_0-auc:0.92638	validation_1-auc:0.75532
# [27]	validation_0-auc:0.92692	validation_1-auc:0.74924
# [28]	validation_0-auc:0.92667	validation_1-auc:0.75062
# [29]	validation_0-auc:0.93838	validation_1-auc:0.78359
# [30]	validation_0-auc:0.93566	validation_1-auc:0.78604
# [31]	validation_0-auc:0.93566	validation_1-auc:0.78604
# [32]	validation_0-auc:0.93381	validation_1-auc:0.78871
# [33]	validation_0-auc:0.93381	validation_1-auc:0.78871
# [34]	validation_0-auc:0.93381	validation_1-auc:0.78871
# [35]	validation_0-auc:0.93374	validation_1-auc:0.78826
# [36]	validation_0-auc:0.93352	validation_1-auc:0.78822
# [37]	validation_0-auc:0.93352	validation_1-auc:0.78822
# [38]	validation_0-auc:0.93352	validation_1-auc:0.78822
# [39]	validation_0-auc:0.93352	validation_1-auc:0.78822
# [40]	validation_0-auc:0.93352	validation_1-auc:0.78822
# [41]	validation_0-auc:0.93352	validation_1-auc:0.78822
# [42]	validation_0-auc:0.93352	validation_1-auc:0.78822
# SCORE:
# 0.3481081081081081
# [0]	validation_0-auc:0.81864	validation_1-auc:0.50156
# [1]	validation_0-auc:0.82147	validation_1-auc:0.53505
# [2]	validation_0-auc:0.87177	validation_1-auc:0.71323
# [3]	validation_0-auc:0.87177	validation_1-auc:0.71323
# [4]	validation_0-auc:0.86489	validation_1-auc:0.70561
# [5]	validation_0-auc:0.87648	validation_1-auc:0.70031
# [6]	validation_0-auc:0.88997	validation_1-auc:0.69991
# [7]	validation_0-auc:0.88109	validation_1-auc:0.69224
# [8]	validation_0-auc:0.89874	validation_1-auc:0.70849
# [9]	validation_0-auc:0.90551	validation_1-auc:0.72074
# [10]	validation_0-auc:0.90244	validation_1-auc:0.72704
# [11]	validation_0-auc:0.89770	validation_1-auc:0.72177
# [12]	validation_0-auc:0.91106	validation_1-auc:0.74649
# [13]	validation_0-auc:0.91361	validation_1-auc:0.72863
# [14]	validation_0-auc:0.91425	validation_1-auc:0.72756
# [15]	validation_0-auc:0.91429	validation_1-auc:0.72652
# [16]	validation_0-auc:0.91429	validation_1-auc:0.72652
# [17]	validation_0-auc:0.91848	validation_1-auc:0.73387
# [18]	validation_0-auc:0.91916	validation_1-auc:0.71781
# [19]	validation_0-auc:0.91903	validation_1-auc:0.72030
# [20]	validation_0-auc:0.91723	validation_1-auc:0.74884
# [21]	validation_0-auc:0.91744	validation_1-auc:0.74752
# [22]	validation_0-auc:0.91901	validation_1-auc:0.74309
# [23]	validation_0-auc:0.91901	validation_1-auc:0.74309
# [24]	validation_0-auc:0.91474	validation_1-auc:0.75509
# [25]	validation_0-auc:0.91482	validation_1-auc:0.75529
# [26]	validation_0-auc:0.91482	validation_1-auc:0.75529
# [27]	validation_0-auc:0.91564	validation_1-auc:0.74931
# [28]	validation_0-auc:0.91533	validation_1-auc:0.75103
# [29]	validation_0-auc:0.92866	validation_1-auc:0.78077
# [30]	validation_0-auc:0.92595	validation_1-auc:0.78517
# [31]	validation_0-auc:0.92595	validation_1-auc:0.78517
# [32]	validation_0-auc:0.92330	validation_1-auc:0.78674
# [33]	validation_0-auc:0.92330	validation_1-auc:0.78674
# [34]	validation_0-auc:0.92330	validation_1-auc:0.78674
# [35]	validation_0-auc:0.92296	validation_1-auc:0.78601
# [36]	validation_0-auc:0.92296	validation_1-auc:0.78601
# [37]	validation_0-auc:0.92296	validation_1-auc:0.78601
# [38]	validation_0-auc:0.92296	validation_1-auc:0.78601
# [39]	validation_0-auc:0.92296	validation_1-auc:0.78601
# [40]	validation_0-auc:0.92296	validation_1-auc:0.78601
# [41]	validation_0-auc:0.92296	validation_1-auc:0.78601
# SCORE:
# 0.3326488706365503
# [0]	validation_0-auc:0.82250	validation_1-auc:0.50156
# [1]	validation_0-auc:0.84559	validation_1-auc:0.52449
# [2]	validation_0-auc:0.89421	validation_1-auc:0.70282
# [3]	validation_0-auc:0.89421	validation_1-auc:0.70282
# [4]	validation_0-auc:0.88439	validation_1-auc:0.69351
# [5]	validation_0-auc:0.90910	validation_1-auc:0.69666
# [6]	validation_0-auc:0.91475	validation_1-auc:0.69928
# [7]	validation_0-auc:0.91053	validation_1-auc:0.69145
# [8]	validation_0-auc:0.92081	validation_1-auc:0.70828
# [9]	validation_0-auc:0.92483	validation_1-auc:0.71934
# [10]	validation_0-auc:0.92462	validation_1-auc:0.72538
# [11]	validation_0-auc:0.92204	validation_1-auc:0.72006
# [12]	validation_0-auc:0.92991	validation_1-auc:0.74444
# [13]	validation_0-auc:0.93029	validation_1-auc:0.72319
# [14]	validation_0-auc:0.93051	validation_1-auc:0.72213
# [15]	validation_0-auc:0.93043	validation_1-auc:0.72094
# [16]	validation_0-auc:0.93050	validation_1-auc:0.72085
# ...
# [5]	validation_0-auc:0.91975	validation_1-auc:0.68545
# [6]	validation_0-auc:0.91953	validation_1-auc:0.69355
# [7]	validation_0-auc:0.91601	validation_1-auc:0.68750
# [8]	validation_0-auc:0.92474	validation_1-auc:0.70422
# [9]	validation_0-auc:0.92841	validation_1-auc:0.71536
# [10]	validation_0-auc:0.93002	validation_1-auc:0.72144
# [11]	validation_0-auc:0.92832	validation_1-auc:0.71693
# [12]	validation_0-auc:0.93497	validation_1-auc:0.74140
# [13]	validation_0-auc:0.93507	validation_1-auc:0.71668
# [14]	validation_0-auc:0.93515	validation_1-auc:0.71555
# [15]	validation_0-auc:0.93495	validation_1-auc:0.71402
# [16]	validation_0-auc:0.93505	validation_1-auc:0.71403
# [17]	validation_0-auc:0.93685	validation_1-auc:0.71886
# [18]	validation_0-auc:0.93685	validation_1-auc:0.69166
# [19]	validation_0-auc:0.93694	validation_1-auc:0.69468
# [20]	validation_0-auc:0.93866	validation_1-auc:0.72563
# [21]	validation_0-auc:0.93887	validation_1-auc:0.72615
# [22]	validation_0-auc:0.93946	validation_1-auc:0.71828
# SCORE:
# 0.3674033149171271
# [0]	validation_0-auc:0.81392	validation_1-auc:0.50156
# [1]	validation_0-auc:0.81592	validation_1-auc:0.53505
# [2]	validation_0-auc:0.86936	validation_1-auc:0.71276
# [3]	validation_0-auc:0.86936	validation_1-auc:0.71276
# [4]	validation_0-auc:0.86275	validation_1-auc:0.70529
# [5]	validation_0-auc:0.87275	validation_1-auc:0.69949
# [6]	validation_0-auc:0.89170	validation_1-auc:0.70252
# [7]	validation_0-auc:0.88287	validation_1-auc:0.69507
# [8]	validation_0-auc:0.90018	validation_1-auc:0.71014
# [9]	validation_0-auc:0.90681	validation_1-auc:0.72184
# [10]	validation_0-auc:0.90372	validation_1-auc:0.72745
# [11]	validation_0-auc:0.89903	validation_1-auc:0.72213
# [12]	validation_0-auc:0.91223	validation_1-auc:0.74732
# [13]	validation_0-auc:0.91451	validation_1-auc:0.72954
# [14]	validation_0-auc:0.91511	validation_1-auc:0.72864
# [15]	validation_0-auc:0.91518	validation_1-auc:0.72729
# [16]	validation_0-auc:0.91518	validation_1-auc:0.72729
# [17]	validation_0-auc:0.91921	validation_1-auc:0.73554
# [18]	validation_0-auc:0.91980	validation_1-auc:0.72074
# [19]	validation_0-auc:0.91965	validation_1-auc:0.72312
# [20]	validation_0-auc:0.91761	validation_1-auc:0.75000
# [21]	validation_0-auc:0.91761	validation_1-auc:0.75000
# [22]	validation_0-auc:0.91920	validation_1-auc:0.74593
# [23]	validation_0-auc:0.91920	validation_1-auc:0.74593
# [24]	validation_0-auc:0.91466	validation_1-auc:0.75702
# [25]	validation_0-auc:0.91468	validation_1-auc:0.75707
# [26]	validation_0-auc:0.91468	validation_1-auc:0.75707
# [27]	validation_0-auc:0.91454	validation_1-auc:0.75664
# [28]	validation_0-auc:0.91425	validation_1-auc:0.75736
# [29]	validation_0-auc:0.92753	validation_1-auc:0.78658
# [30]	validation_0-auc:0.92470	validation_1-auc:0.79033
# [31]	validation_0-auc:0.92470	validation_1-auc:0.79033
# [32]	validation_0-auc:0.92220	validation_1-auc:0.79112
# [33]	validation_0-auc:0.92220	validation_1-auc:0.79112
# [34]	validation_0-auc:0.92220	validation_1-auc:0.79112
# [35]	validation_0-auc:0.92273	validation_1-auc:0.78831
# [36]	validation_0-auc:0.92255	validation_1-auc:0.78820
# [37]	validation_0-auc:0.92255	validation_1-auc:0.78820
# [38]	validation_0-auc:0.92255	validation_1-auc:0.78820
# [39]	validation_0-auc:0.92255	validation_1-auc:0.78820
# [40]	validation_0-auc:0.92255	validation_1-auc:0.78820
# [41]	validation_0-auc:0.92255	validation_1-auc:0.78820
# SCORE:
# 0.3561030235162374
# [0]	validation_0-auc:0.83101	validation_1-auc:0.50156
# [1]	validation_0-auc:0.85499	validation_1-auc:0.52449
# [2]	validation_0-auc:0.89972	validation_1-auc:0.69559
# [3]	validation_0-auc:0.89972	validation_1-auc:0.69559
# [4]	validation_0-auc:0.89147	validation_1-auc:0.68993
# [5]	validation_0-auc:0.91190	validation_1-auc:0.69094
# [6]	validation_0-auc:0.91609	validation_1-auc:0.69617
# [7]	validation_0-auc:0.91244	validation_1-auc:0.69020
# [8]	validation_0-auc:0.92200	validation_1-auc:0.70554
# [9]	validation_0-auc:0.92586	validation_1-auc:0.71657
# [10]	validation_0-auc:0.92604	validation_1-auc:0.72274
# [11]	validation_0-auc:0.92370	validation_1-auc:0.71739
# [12]	validation_0-auc:0.93113	validation_1-auc:0.74154
# [13]	validation_0-auc:0.93146	validation_1-auc:0.71751
# [14]	validation_0-auc:0.93168	validation_1-auc:0.71704
# [15]	validation_0-auc:0.93153	validation_1-auc:0.71566
# [16]	validation_0-auc:0.93153	validation_1-auc:0.71566
# [17]	validation_0-auc:0.93392	validation_1-auc:0.72146
# [18]	validation_0-auc:0.93395	validation_1-auc:0.70092
# [19]	validation_0-auc:0.93380	validation_1-auc:0.70316
# [20]	validation_0-auc:0.93451	validation_1-auc:0.73453
# [21]	validation_0-auc:0.93466	validation_1-auc:0.73353
# SCORE:
# 0.39123630672926446
# [0]	validation_0-auc:0.82250	validation_1-auc:0.50156
# [1]	validation_0-auc:0.84489	validation_1-auc:0.52449
# [2]	validation_0-auc:0.89125	validation_1-auc:0.70372
# [3]	validation_0-auc:0.89125	validation_1-auc:0.70372
# [4]	validation_0-auc:0.87962	validation_1-auc:0.69257
# [5]	validation_0-auc:0.90614	validation_1-auc:0.70005
# [6]	validation_0-auc:0.91280	validation_1-auc:0.70167
# [7]	validation_0-auc:0.90797	validation_1-auc:0.69288
# [8]	validation_0-auc:0.91897	validation_1-auc:0.71068
# [9]	validation_0-auc:0.92330	validation_1-auc:0.72170
# [10]	validation_0-auc:0.92234	validation_1-auc:0.72723
# [11]	validation_0-auc:0.91932	validation_1-auc:0.72188
# [12]	validation_0-auc:0.92783	validation_1-auc:0.74600
# [13]	validation_0-auc:0.92840	validation_1-auc:0.72743
# [14]	validation_0-auc:0.92871	validation_1-auc:0.72610
# [15]	validation_0-auc:0.92862	validation_1-auc:0.72438
# [16]	validation_0-auc:0.92862	validation_1-auc:0.72438
# [17]	validation_0-auc:0.93114	validation_1-auc:0.73213
# [18]	validation_0-auc:0.93104	validation_1-auc:0.71792
# [19]	validation_0-auc:0.93085	validation_1-auc:0.71991
# [20]	validation_0-auc:0.93039	validation_1-auc:0.74873
# [21]	validation_0-auc:0.93061	validation_1-auc:0.74763
# [22]	validation_0-auc:0.93154	validation_1-auc:0.74164
# [23]	validation_0-auc:0.93154	validation_1-auc:0.74164
# [24]	validation_0-auc:0.92854	validation_1-auc:0.75391
# [25]	validation_0-auc:0.92846	validation_1-auc:0.75416
# [26]	validation_0-auc:0.92846	validation_1-auc:0.75416
# [27]	validation_0-auc:0.92780	validation_1-auc:0.75359
# [28]	validation_0-auc:0.92780	validation_1-auc:0.75359
# [29]	validation_0-auc:0.93957	validation_1-auc:0.78767
# [30]	validation_0-auc:0.93692	validation_1-auc:0.78933
# [31]	validation_0-auc:0.93692	validation_1-auc:0.78933
# [32]	validation_0-auc:0.93502	validation_1-auc:0.79073
# [33]	validation_0-auc:0.93502	validation_1-auc:0.79073
# [34]	validation_0-auc:0.93502	validation_1-auc:0.79073
# [35]	validation_0-auc:0.93466	validation_1-auc:0.79016
# [36]	validation_0-auc:0.93466	validation_1-auc:0.79016
# [37]	validation_0-auc:0.93466	validation_1-auc:0.79016
# [38]	validation_0-auc:0.93466	validation_1-auc:0.79016
# [39]	validation_0-auc:0.93466	validation_1-auc:0.79016
# [40]	validation_0-auc:0.93466	validation_1-auc:0.79016
# [41]	validation_0-auc:0.93466	validation_1-auc:0.79016
# SCORE:
# 0.3547297297297297
# 100%|██████████████████████████████████████████████| 100/100 [01:20<00:00,  1.24trial/s, best loss: -0.4067524115755627]

# %% [markdown]
# ### 8.1.3. Results ¶

# %%
print("The best hyperparameters are : ","\n")
print(best_hyperparams)
# Out:
# The best hyperparameters are :
#
# {'colsample_bytree': 0.6144705743579607, 'gamma': 1.508666259260115, 'max_depth': 12.0, 'min_child_weight': 5.0, 'reg_alpha': 123.0, 'reg_lambda': 0.7646640091328795}

# %% [markdown]
# ### 8.2.2. Base Model Performance

# %%
space={'max_depth': 5.0,
        'gamma': 5.823651951003387,
        'reg_alpha' : 91.0,
        'reg_lambda' : 0.8844899888803859,
        'colsample_bytree' : 0.6732348378984229,
        'min_child_weight' : 9.0,
        'n_estimators': 180,
        'seed': 0
    }

# %%
clf=XGBClassifier(
                n_estimators =space['n_estimators'], max_depth = int(space['max_depth']), gamma = space['gamma'],
                reg_alpha = int(space['reg_alpha']),min_child_weight=int(space['min_child_weight']),
                colsample_bytree=int(space['colsample_bytree']))

#clf.fit(x_test, y_test)
clf.fit(x_balanced, y_balanced)
# Out:
# [13:55:20] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117766796/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0, enable_categorical=False,
#               gamma=5.823651951003387, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=5, min_child_weight=9, missing=nan,
#               monotone_constraints='()', n_estimators=180, n_jobs=12,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=91, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
xgb_bal, cm = performance_test('XGboost bal', clf, x_test, y_test)
xgb_bal
# Out:
#              precision  recall  f1_score  roc_auc_score   mcc
# XGboost bal      0.350   0.811     0.489          0.713 0.344

# %%
 # confusion matrix
sns.heatmap(cm, annot=True, fmt='d').set_title('Confusion Matrix');

# %% [markdown]
# # 8.0. Performance Metrics

# %% [markdown]
# ## 8.1. Confusion Matrix

# %%
fig, axes = plt.subplots(2, 2, figsize=(15,10))

fig.suptitle('Model Comparasion')

cm_viz = ConfusionMatrix(logit,  classes=['not churn', 'churn'], support=True, cmap='YlGnBu', ax=axes[0][0])
cm_viz.fit(x_balanced, y_balanced)  
cm_viz.score(x_test, y_test)
cm_viz.finalize()

cm_viz = ConfusionMatrix(svm,  classes=['not churn', 'churn'], support=True, cmap='YlGnBu', ax=axes[0][1])
cm_viz.fit(x_balanced, y_balanced)  
cm_viz.score(x_test, y_test)
cm_viz.finalize()

cm_viz = ConfusionMatrix(rf,  classes=['not churn', 'churn'], support=True, cmap='YlGnBu', ax=axes[1][0])
cm_viz.fit(x_balanced, y_balanced)  
cm_viz.score(x_test, y_test)
cm_viz.finalize()

cm_viz = ConfusionMatrix(xgb,  classes=['not churn', 'churn'], support=True, cmap='YlGnBu', ax=axes[1][1])
cm_viz.fit(x_balanced, y_balanced)  
cm_viz.score(x_test, y_test)
cm_viz.finalize()

# %%
# predictions
xgb_y_pred = cross_val_predict(xgb, x_balanced, y_balanced, cv=10)

# confusion matrix
xgb_cm = confusion_matrix(y_balanced, xgb_y_pred)

# dataframe for heatmap
xgb_cm_df = pd.DataFrame(xgb_cm, columns=['predicted_not_churn', 'predicted_churn'], index=['actual_not_churn', 'actual_churn'])

# confusion matrix heatmap
sns.heatmap(xgb_cm_df, annot=True, fmt='d').set_title('Confusion Matrix');
# Out:
# [13:55:23] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117766796/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:55:24] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117766796/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:55:24] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117766796/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:55:25] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117766796/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:55:25] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117766796/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:55:26] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117766796/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:55:26] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117766796/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:55:26] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117766796/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:55:27] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117766796/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:55:27] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117766796/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %% [markdown]
# # 9.0. Business Performance

# %% [markdown]
# ## 9.1. Model Performance

# %% [markdown]
# ### 9.1.1. Precision and recall versus decision threshold

# %%
# calculate model predicted probabilities
y_probas = clf.predict_proba(x_test)

# get positive class probabilities
y_scores = y_probas[:,1]
y_scores
# Out:
# array([0.3089777 , 0.28653514, 0.25836524, ..., 0.8887917 , 0.4645589 ,
#        0.5334842 ], dtype=float32)

# %%
 # compute precision and recall for all possible thresholds
precisions, recalls, thresholds = precision_recall_curve(y_test, y_scores)

# %%
# current recall from the model
recall_model = xgb_bal['recall'][0]

# current precision from the model
precision_model = xgb_bal['precision'][0]

# %%
 # get current precision index
prec_index = np.where(precisions==precision_model)
prec_index
# Out:
# (array([650]),)

# %%
# get current threshold of the model
threshold_model = thresholds[prec_index]
threshold_model
# Out:
# array([0.50020564], dtype=float32)

# %%
 # Plot precision and recall versus threshold

# figure size
plt.figure(figsize=(12,6))

plt.plot(thresholds, precisions[:-1], "b--", label='Precision', linewidth=2)
plt.plot(thresholds, recalls[:-1], "g-", label='Recall', linewidth=2)
plt.legend(loc='center right', fontsize=16)
plt.xlabel("Threshold", fontsize=16)
plt.xticks(np.arange(0, 1.01, step=0.1))
plt.yticks(np.arange(0, 1.01, step=0.1))
plt.grid(True)

# plot current precision and recall from the model
plt.plot([threshold_model, threshold_model], [0.0, precision_model], 'r:')
plt.plot([0.0, threshold_model], [precision_model, precision_model], 'r:')
plt.plot([0.0, threshold_model], [recall_model, recall_model], 'r:')
plt.plot([threshold_model], [precision_model], 'ro')
plt.plot([threshold_model], [recall_model], 'ro')
plt.axis([0, 1, 0, 1])
plt.title('Precision and recall versus the decision threshold', fontsize=16)
plt.show()

# %% [markdown]
# ### 9.1.2 Precision versus Recall

# %%
 # plot precision versus recall

# figure size
plt.figure(figsize=(12,6))

plt.plot(recalls, precisions, 'b-', linewidth=2)
plt.xlabel('Recall', fontsize=16)
plt.ylabel('Precision', fontsize=16)
plt.axis([0, 1, 0, 1])

# plot current precision and recall from the model
plt.plot([recall_model, recall_model], [0.0, precision_model], 'r:')
plt.plot([0.0, recall_model], [precision_model, precision_model], 'r:')
plt.plot([recall_model], [precision_model], 'ro')
plt.grid(True)
plt.title('Precision versus Recall', fontsize=16)
plt.show()

# %% [markdown]
# ### 9.1.4. Lift Curve and Cumulative Gains Curve

# %% [markdown]
# **Lift Curve**
# - The lift curve uses the returned probability of a classification model to assess how the model is performing, and how well it is identifying the positive or negative instances of the dataset.
# - By ordering the data from the highest to the smallest probability, the highest probability appear on the left of the graph, usually along with the highest Lift scores.
# - Provides a quick way to get an estimate of how the algorithm is performing.
# - The lift chart provides an easy way to visualize how many times better applying the model is than random selection for any percentage of the ranked records.
# - The greater the area between the lift curve and the baseline, the better the model.

# %%
# plot Lift curve
skplt.metrics.plot_lift_curve(y_test, y_probas, figsize=(8,6))
plt.legend(loc='center right', fontsize=12)
plt.show()

# %% [markdown]
# - The Lift curve shows that if 20% of the customers are contacted, using the prediction of the model should reach 60% of customers in churn. The y-value of the lift curve at 20% is 60 / 20 = 3.

# %% [markdown]
# **Cumulative Gains Curve**
# - The left hand side of the x-axis start with the observations that have the highest probability of belonging to the class of interest.
# - The x axis tell us what percentage of the observations are being considered. In this case, it is a percentage of the 2,000 clients from the test set.
# - The y axis (Gain) indicates the percentage of positive responses.
# - In this case, it is the percentage of the 407 positive responses from the test set.Question to ask and answer with this plot: when the model is applied to the data, and the most likely X percent of the records are selected, what percentage of the actual records you’re interested can you expect to find?

# %%
# plot cumulative gains curve
skplt.metrics.plot_cumulative_gain(y_test, y_probas, figsize=(8,6))
plt.show()

# %% [markdown]
# - Check Lift and Cumulative Gains values

# %%
# copy test_set
lift_df = test_set_.copy()

 # model predictions
y_pred = clf.predict(x_test)

# add predictions and predicted probabilities according the model
lift_df['predictions'] = y_pred
lift_df['probabilities'] = y_scores

# sort lift_df according predicted probabilities
lift_df = lift_df.sort_values('probabilities', ascending=False)

# %%
# set percentage of the sample (percentage of clients to contact in order to avoid churn)
sample_pc = 0.2

# calculate the size of the percentage of the sample
top_sample_pc = np.ceil((len(lift_df['exited'])*sample_pc)).astype(int)

# select top rated clients (top predicted probabilities)
clients_top = lift_df.iloc[:top_sample_pc]

# calculate cumulative gain
cumulative_gain = clients_top['exited'].sum() / test_set_['exited'].sum()

# calculate lift
lift = cumulative_gain / sample_pc

# print results
print('sample percentage: {}%'.format(sample_pc*100))
print('Cumulative gain: {:,.2f}'.format(cumulative_gain))
print('Lift: {:,.2f}'.format(lift))
# Out:
# sample percentage: 20.0%
# Cumulative gain: 0.55
# Lift: 2.73

# %% [markdown]
# # 9.2. Business Performance

# %% [markdown]
# ## 9.2.1. Current Churn Rate

# %% [markdown]
# - Current churn rate

# %%
 # calculate current churn rate
churn_rate = test_set_['exited'].value_counts(normalize=True)*100
print('The current churn Rate is {:,.2f}%'.format(churn_rate[1]))
# Out:
# The current churn Rate is 20.35%

# %% [markdown]
# - How the churn rate varies per month?
#
#
#
#     It is not possible to calculate how the churn rate varies per month, as there's no month information in the available dataset.
#     What can be calculated is the churn variation per tenure (number of years that the customer was active).

# %%
churn_rate_ten = (test_set_[test_set_['tenure']==2]['exited'].sum() / len(test_set_[test_set_['tenure']==2]))*100
churn_rate_ten
# Out:
# 21.890547263681594

# %%
 # get tenure values
ten_values = test_set_['tenure'].value_counts()
ten_values = np.array(ten_values.index)
churn_list = []

# calculate churn rate per tenure
for ten in ten_values:
    churn_rate_ten = (test_set_[test_set_['tenure']==ten]['exited'].sum() / len(test_set_[test_set_['tenure']==ten]))*100
    churn_list.append(churn_rate_ten)

# %%
# create churn rate per tenure dataframe
churn_ten_df = pd.DataFrame({'churn_rate': churn_list, 'tenure': ten_values})
churn_ten_df = churn_ten_df.sort_values('tenure')
churn_ten_df.round(2)
# Out:
#     churn_rate  tenure
# 10      23.080       0
# 0       23.010       1
# 4       21.890       2
# 7       22.950       3
# 6       23.320       4
# 2       22.640       5
# 1       19.550       6
# 3       15.310       7
# 5       17.410       8
# 8       20.000       9
# 9       12.750      10

# %%
 # plot churn rate variation per tenure
plt.figure(figsize=(12,6))
sns.barplot(x='tenure', y='churn_rate', data=churn_ten_df).set_title('Churn Rate variation per Tenure');

# %% [markdown]
# - What's the model's performance to label the clients as churns?
#
# - The model has a precision of 73.4% to label the clients as churns. The model can detect 52.1% of clients in churn.

# %% [markdown]
# ## 9.2.3. Bank Revenue

# %% [markdown]
# ### 9.2.3.1. General Business Results

# %% [markdown]
# - What's the company's revenue, if the company avoids the customers to get into churn through the developed model?
#
# - Bank account return per client:
#     - 15% for clients with estimated income lower than the average;
#     - 20% for clients with estimated income greater than the average.

# %%
# calculate bank account return per client

# create auxiliary dataset
business_df = test_set_.copy()

business_df['return_client'] = business_df.\
apply(lambda x: x['estimated_salary']*0.15 if x['estimated_salary'] < business_df['estimated_salary'].mean() else x['estimated_salary']*0.2, axis=1)

# %% [markdown]
# - Calculate current total return of all clients

# %%
 # calculate current total return of all clients
return_total = business_df['return_client'].sum()
print('Total current return of all clients: {:,.2f}'.format(return_total))
# Out:
# Total current return of all clients: 38,079,850.98

# %% [markdown]
# - Calculate revenue loss if all clients in churn leave the bank

# %%
 # number of clients in churn
clients_churn = business_df['exited'].value_counts()[1]

# calculate total revenue loss
total_loss = business_df[business_df['exited']==1]['return_client'].sum()
print('Total revenue loss if all {} clients in churn leave the bank: {:,.2f}.'.format(clients_churn, total_loss))
print('The total revenue loss represents {:,.2f}% of total current return.'.format((total_loss/return_total)*100))
# Out:
# Total revenue loss if all 407 clients in churn leave the bank: 7,491,850.97.
# The total revenue loss represents 19.67% of total current return.

# %%
 # model predictions
y_pred = clf.predict(x_test)

# dataframe with predictions and predicted probabilities
business_df['predictions'] = y_pred
business_df['probabilities'] = y_scores

# %% [markdown]
# - Calculate company's revenue , if the company avoids the customers to get into churn through the developed model

# %%
 # filter clients in churn according model and dataset
aux = business_df[(business_df['exited']==1) & (business_df['predictions']==1)]

# number of clients to recover
clients_recover = len(aux)
# clients ratio w.r.t. total clients in churn
clients_ratio = (clients_recover / clients_churn)*100

# revenue if clients don't get in churn
revenue = aux['return_client'].sum()
# revenue ratio w.r.t. revenue loss
revenue_ratio = (revenue / total_loss)*100

print("Company's recovered revenue if {} clients don't get into churn through the model: {:,.2f}".\
      format(clients_recover, revenue))
print('That represents {:,.2f}% of clients labeled as in churn and {:,.2f}% of the total revenue loss'.\
      format(clients_ratio, revenue_ratio))
# Out:
# Company's recovered revenue if 330 clients don't get into churn through the model: 6,155,495.99
# That represents 81.08% of clients labeled as in churn and 82.16% of the total revenue loss

# %% [markdown]
# - Sort Customers according model's churn probability predictions.

# %%
 # sort business_df according predicted probabilities
business_df = business_df.sort_values('probabilities', ascending=False)

# %% [markdown]
# #### 9.2.3.2. Customer Incentive to Maximize ROI - Alternative 1

# %% [markdown]
# **Top 100 clients with highest churn probability.**
# - Which customers could receive an incentive and at what cost, in order to maximize the ROI (Return on investment)? (the sum of incentives shall not exceed BRL 10,000.00
#
#
#  Top 100 clients with highest churn probability
#
#
# - Incentive per client: $100.
# - If churn (exited) is True, then returns recovered revenue per client.
# - If churn (exited) is False, then returns zero.
# - The profit is the difference between recovered revenue and the incentive per client.

# %%
# select top 100 clients with highest churn probability
clients_top_100 = business_df.iloc[:100]

# set incentive per client
clients_top_100['incentive'] = 100

# calculate recovered revenue per client
clients_top_100['rec_revenue'] = clients_top_100.\
apply(lambda x: x['return_client'] if x['exited']==1 else 0, axis=1)

# calculate profit per client
clients_top_100['profit'] = clients_top_100['rec_revenue'] - clients_top_100['incentive']

# calculate total recovered revenue
revenue = clients_top_100['rec_revenue'].sum()

# calculate revenue loss recovered (%)
loss_recovered = (revenue / total_loss)*100

# calculate the amount of investments (sum of incentives)
investment = clients_top_100['incentive'].sum()

# calculate the profit
profit = clients_top_100['profit'].sum()

# calculate ROI
roi = (profit / investment)*100

# calculate possible churn reduction in %
churn_model = clients_top_100[(clients_top_100['exited']==1) & (clients_top_100['predictions']==1)]
churn_red = (len(churn_model) / len(business_df[business_df['exited']==1]))*100

print('Recovered Revenue: {:,.2f}'.format(revenue))
print('% Recovered from Total Revenue loss: {:,.2f}%'.format(loss_recovered))
print('Investment: {:,.2f}'.format(investment))
print('Profit: {:,.2f}'.format(profit))
print('ROI: {:,.2f}%'.format(roi))
print('Potential clients recovered acc. model: {}'.format(len(churn_model)))
print('Potential churn reduction: {:,.2f}%'.format(churn_red))
# Out:
# Recovered Revenue: 1,331,513.05
# % Recovered from Total Revenue loss: 17.77%
# Investment: 10,000.00
# Profit: 1,321,513.05
# ROI: 13,215.13%
# Potential clients recovered acc. model: 76
# Potential churn reduction: 18.67%

# %% [markdown]
# #### 9.2.3.3. Customer Incentive to Maximize ROI - Alternative 2

# %% [markdown]
# **Top 200 clients with highest churn probability.**
# - Which customers could receive an incentive and at what cost, in order to maximize the ROI (Return on investment)? (the sum of incentives shall not exceed BRL 10,000.00
#
#
#  Top 200 clients with highest churn probability.
#
# - Incentive per client: $50.
# - If churn (exited) is True, then returns recovered revenue per client.
# - If churn (exited) is False, then returns zero.
# - The profit is the difference between recovered revenue and the incentive per client.

# %%
# select top 200 clients with highest churn probability
clients_top_200 = business_df.iloc[:200]

# set incentive per client
clients_top_200['incentive'] = 50

# calculate recovered revenue per client
clients_top_200['rec_revenue'] = clients_top_200.\
apply(lambda x: x['return_client'] if x['exited']==1 else 0, axis=1)

# calculate profit per client
clients_top_200['profit'] = clients_top_200['rec_revenue'] - clients_top_200['incentive']

# calculate total recovered revenue
revenue = clients_top_200['rec_revenue'].sum()

# calculate revenue loss recovered (%)
loss_recovered = (revenue / total_loss)*100

# calculate the amount of investments (sum of incentives)
investment = clients_top_200['incentive'].sum()

# calculate the profit
profit = clients_top_200['profit'].sum()

# calculate ROI
roi = (profit / investment)*100

# calculate possible churn reduction in %
churn_model = clients_top_200[(clients_top_200['exited']==1) & (clients_top_200['predictions']==1)]
churn_red = (len(churn_model) / len(business_df[business_df['exited']==1]))*100

print('Recovered Revenue: {:,.2f}'.format(revenue))
print('% Recovered from Total Revenue loss: {:,.2f}%'.format(loss_recovered))
print('Investment: {:,.2f}'.format(investment))
print('Profit: {:,.2f}'.format(profit))
print('ROI: {:,.2f}%'.format(roi))
print('Potential clients recovered acc. model: {}'.format(len(churn_model)))
print('Potential churn reduction: {:,.2f}%'.format(churn_red))
# Out:
# Recovered Revenue: 2,562,327.71
# % Recovered from Total Revenue loss: 34.20%
# Investment: 10,000.00
# Profit: 2,552,327.71
# ROI: 25,523.28%
# Potential clients recovered acc. model: 140
# Potential churn reduction: 34.40%

# %% [markdown]
# #### 9.2.3.4. Customer Incentive to Maximize ROI - Alternative 3

# %% [markdown]
# **Maximum returned value with "0-1 Knapsack-Problem" approach**
#
# - Goal: select the optimal combination of clients that maximize the total returned value , without exceeding the total weight constraint.
# - In this case, each client has a "weight": the financial incentive that will be given in order to avoid the churn.
# - The total weight constraint is the total amount available to give the incentives: $ 10,000.00.
# - The incentive can either be offered or not: 0-1 (0-1 Knapsack).
#
#
# - Please see 0.2. Helper Functions section for knapsack function details.

# %% [markdown]
# - Set incentive per client and filter clients in churn according model and dataset

# %%
# set financial incentive $ 100 per client
business_df['incentive'] = 100

# filter clients in churn according model
aux = business_df[business_df['predictions']==1]

# %% [markdown]
# - Apply knapsack function and calculate business results.

# %%
 # set parameters for the knapsack function
val = aux['return_client'].astype(int).values # return per client
wt = aux['incentive'].values # incentive value per client
investment = 10000 # total amount of incentive according the problem

# calculate revenue with knapsack function. For more details, please see 0.2. Helper Functions section.
max_val, keep = knapsack(investment, wt, val)

# dataframe with selected clients that maximizes output value
aux = aux[keep]

# calculate recovered revenue per client
aux['rec_revenue'] = aux.\
apply(lambda x: x['return_client'] if x['exited']==1 else 0, axis=1)

# calculate profit per client
aux['profit'] = aux['rec_revenue'] - aux['incentive']

# calculate total recovered revenue
revenue = aux['rec_revenue'].sum()

# calculate revenue loss recovered (%)
loss_recovered = (revenue / total_loss)*100

# calculate the amount of investments (sum of incentives)
investment = aux['incentive'].sum()

# calculate the profit
profit = aux['profit'].sum()

# calculate ROI
roi = (profit / investment)*100

# calculate possible churn reduction in %
churn_model = aux[(aux['exited']==1) & (aux['predictions']==1)]
churn_red = (len(churn_model) / len(business_df[business_df['exited']==1]))*100

print('Recovered Revenue: {:,.2f}'.format(revenue))
print('% Recovered from Total Revenue loss: {:,.2f}%'.format(loss_recovered))
print('Investment: {:,.2f}'.format(investment))
print('Profit: {:,.2f}'.format(profit))
print('ROI: {:,.2f}%'.format(roi))
print('Potential clients recovered acc. model: {}'.format(len(churn_model)))
print('Potential churn reduction: {:,.2f}%'.format(churn_red))
# Out:
# Recovered Revenue: 1,292,124.41
# % Recovered from Total Revenue loss: 17.25%
# Investment: 10,000.00
# Profit: 1,282,124.41
# ROI: 12,821.24%
# Potential clients recovered acc. model: 34
# Potential churn reduction: 8.35%

# %% [markdown]
# #### 9.2.3.5. Customer Incentive to Maximize ROI - Alternative 4

# %% [markdown]
# - The Realistic approach and Maximum returned value with "0-1 Knapsack-Problem" approach

# %% [markdown]
# - Some customers will leave no matter what: p(churn) > 0.99
# - Some might stay but only with a $200 incentive: 0.95 < p(churn) < 0.99

# %% [markdown]
# - Some will stay with a $100 incentive: 0.90 < p(churn) < 0.95

# %% [markdown]
# - Others will stay with a $50 incentive: p(churn) < 0.90

# %%
 # list of available incentives as stated above
# the incentive of 20000 is for clients with p(churn) > 0.99, it will be discarded in the knapsack function
incentives_list = [20000, 200, 100, 50]
incentives = []
n = len(business_df)

# set incentive value according churn predicted probability
for i in range(n):
    entry = business_df.iloc[i]
    if entry['probabilities'] >= 0.99:
        incentives.append(incentives_list[0])
    elif entry['probabilities'] >= 0.95 and entry['probabilities'] < 0.99:
        incentives.append(incentives_list[1])
    elif entry['probabilities'] >= 0.90 and entry['probabilities'] < 0.95:
        incentives.append(incentives_list[2])
    else:
        incentives.append(incentives_list[3])
business_df['incentive'] = incentives

# %%
# filter clients in churn according model
aux = business_df[business_df['predictions']==1]

# set parameters for the knapsack function
val = aux['return_client'].astype(int).values # return per client
wt = aux['incentive'].values # incentive value per client
investment = 10000 # total amount of incentive according the problem

# calculate revenue with knapsack function
max_val, keep = knapsack(investment, wt, val)

# dataframe with selected clients that maximizes output value
aux = aux[keep]

# calculate recovered revenue per client
aux['rec_revenue'] = aux.\
apply(lambda x: x['return_client'] if x['exited']==1 else 0, axis=1)

# calculate profit per client
aux['profit'] = aux['rec_revenue'] - aux['incentive']

# calculate total recovered revenue
revenue = aux['rec_revenue'].sum()

# calculate revenue loss recovered (%)
loss_recovered = (revenue / total_loss)*100

# calculate the amount of investments (sum of incentives)
investment = aux['incentive'].sum()

# calculate the profit
profit = aux['profit'].sum()

# calculate ROI
roi = (profit / investment)*100

# calculate possible churn reduction in %
churn_model = aux[(aux['exited']==1) & (aux['predictions']==1)]
churn_red = (len(churn_model) / len(business_df[business_df['exited']==1]))*100

print('Recovered Revenue: {:,.2f}'.format(revenue))
print('% Recovered from Total Revenue loss: {:,.2f}%'.format(loss_recovered))
print('Investment: {:,.2f}'.format(investment))
print('Profit: {:,.2f}'.format(profit))
print('ROI: {:,.2f}%'.format(roi))
print('Potential clients recovered acc. model: {}'.format(len(churn_model)))
print('Potential churn reduction: {:,.2f}%'.format(churn_red))
# Out:
# Recovered Revenue: 2,071,963.80
# % Recovered from Total Revenue loss: 27.66%
# Investment: 10,000.00
# Profit: 2,061,963.80
# ROI: 20,619.64%
# Potential clients recovered acc. model: 58
# Potential churn reduction: 14.25%

# %% [markdown]
# ### 9.2.4. Business Performance Summary

# %% [markdown]
# - Model's performance and results report:
#     - What's the company's current churn rate?
#     - How the churn rate varies per month?What's the model's performance to label the clients as churns?
#     - What's the company's revenue, if the company avoids the customers to get into churn through the developed model?
#
#
# - Possible measure: discount coupon or other financial incentive.
#     - Which customers could receive an incentive and at what cost, in order to maximize the ROI (Return on investment)? (the sum of incentives shall not exceed BRL 10,000.00
#
#
# - The company's **current churn rate is 20%.**
# - It is not possible to determine the churn variation per month, as the available data does not have information per month. What can be calculated is the churn variation per tenure (number of years that the customer was active). Note: this churn variation considers only the proportion of churn in the tenure itself.

# %%
churn_ten_df.round(2)
# Out:
#     churn_rate  tenure
# 10      23.080       0
# 0       23.010       1
# 4       21.890       2
# 7       22.950       3
# 6       23.320       4
# 2       22.640       5
# 1       19.550       6
# 3       15.310       7
# 5       17.410       8
# 8       20.000       9
# 9       12.750      10

# %% [markdown]
# - The model has a precision of 73.4% to label the clients as churns.
# - The model can detect 52.1% of clients in churn.
#
# Total current revenue considering all clients: **38,079,850.98.**
#     - Total revenue loss if all 407 clients in churn leave the bank: **7,491,850.97 (19.67% of current total revenue).**

# %% [markdown]
# **Ideal Scenario according the model:**
# - Company's revenue if 212 clients don't get into churn through the model: **4,064,569.35.**
# - That represents **52.09% of clients** labeled as in churn and **54.25% of the total revenue loss.**
#
#
#  **Discount coupon or other financial incentive - Optimal Solution**

# %% [markdown]
# **Realistic approach (Alternative 4)**
# Incentive value per client according model's predicted churn probability-range and maximum returned value with "0-1 Knapsack-Problem" approach.
#
# - Recovered Revenue: 3,381,860.54
# - **% Recovered from Total Revenue loss: 45.14%**
# - Investment: 10,000.00
# - **Profit: 3,371,860.54**
# - ROI: 33,718.61%
# - Potential clients recovered acc. model: 131
# - **Potential churn reduction: 32.19%**

# %% [markdown]
# ### 9.2.5. Next Steps

# %% [markdown]
# - Better evaluate and experiment feature application in the current model in order to improve its results.
# - Train another model in order to improve the overall performance: F1-Score, MCC, Precision and Recall.
# - Data Balance experiment and evaluation.
